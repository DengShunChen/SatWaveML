# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import sqlite3
import json

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# ## read in data from local json database
# read in data

# %%
df = pd.read_json('../ML_data.json')

# %% [markdown]
# ## clean data

# %%
from datetime import datetime
dataset = df[['STN','ST','DATETIME','H','Temp','P','Vm','Vmsat']]

df_index = (dataset['DATETIME']>datetime(2015,1,1,0)) & (dataset['DATETIME']<datetime(2020,1,1,0))
dataset = dataset[df_index]

#stnlist=['新竹浮標','龜山島浮標','臺東外洋浮標','龍洞浮標','小琉球浮標','花蓮浮標','東沙島浮標','馬祖浮標']
#stnlist=['東沙島浮標']
#stnlist=['新竹浮標','臺東外洋浮標','東沙島浮標','馬祖浮標']
stnlist=['臺東外洋浮標','東沙島浮標','馬祖浮標']

dataset = dataset[dataset['STN'].isin(stnlist)]
dataset = dataset.dropna()

# %%
dataset.isna().sum()
# Out:
# STN         0
# ST          0
# DATETIME    0
# H           0
# Temp        0
# P           0
# Vm          0
# Vmsat       0
# dtype: int64

# %% [markdown]
# Drop those rows to keep this initial tutorial simple.

# %%
dataset = dataset.dropna()
dataset.tail()
# Out:
#          STN     ST            DATETIME     H  Temp       P    Vm      Vmsat
# 877101  馬祖浮標  C6W08 2018-12-30 20:00:00  3.52  16.3  1030.6  14.0  16.348304
# 877107  馬祖浮標  C6W08 2018-12-31 02:00:00  2.73  16.1  1030.4  12.4  14.287296
# 877113  馬祖浮標  C6W08 2018-12-31 08:00:00  3.51  16.1  1032.7  12.9  14.614159
# 877119  馬祖浮標  C6W08 2018-12-31 14:00:00  3.10  15.5  1029.3  12.5  14.517667
# 877125  馬祖浮標  C6W08 2018-12-31 20:00:00  3.33  15.8  1031.2  12.9  13.381326

# %%
# %matplotlib inline
plt.figure(figsize=(16,8),dpi=200)
g = sns.FacetGrid(dataset, col="STN", col_wrap=2, height=3, aspect=3)
g.map(sns.lineplot, 'DATETIME','Vm',color='k')
g.map(sns.lineplot, 'DATETIME','Vmsat',color='r')
plt.legend(labels=['Buoy Wind','Satellite Wind'])

# %%
dataset.pop('DATETIME')
dataset.pop('ST')
dataset.pop('STN')
# Out:
# 149823    臺東外洋浮標
# 149829    臺東外洋浮標
# 149835    臺東外洋浮標
# 149841    臺東外洋浮標
# 149847    臺東外洋浮標
#            ...
# 877101      馬祖浮標
# 877107      馬祖浮標
# 877113      馬祖浮標
# 877119      馬祖浮標
# 877125      馬祖浮標
# Name: STN, Length: 9078, dtype: object

# %% [markdown]
# ### Split the data into train and test
#
# Now split the dataset into a training set and a test set.
#
# Use the test set in the final evaluation of your models.

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %% [markdown]
# ### Inspect the data
#
# Have a quick look at the joint distribution of a few pairs of columns from the training set.

# %%
sns.pairplot(train_dataset[['H', 'P', 'Temp', 'Vm','Vmsat']], diag_kind='kde')

# %% [markdown]
# Also look at the overall statistics, note how each feature covers a very different range:

# %%
train_dataset.describe().transpose()
# Out:
#         count         mean       std         min          25%          50%  \
# H      7262.0     1.747535  1.047002    0.240000     0.970000     1.510000
# Temp   7262.0    26.327279  4.359655   10.600000    25.000000    27.300000
# P      7262.0  1011.084426  6.154957  975.700000  1007.100000  1010.400000
# Vm     7262.0     6.649766  3.067025    1.100000     4.200000     6.500000
# Vmsat  7262.0     7.535785  3.547133    0.143646     4.826973     7.420243
#
#                75%          max
# H         2.280000    12.300000
# Temp     29.200000    34.200000
# P      1015.200000  1035.200000
# Vm        8.800000    26.800000
# Vmsat     9.935997    50.117094

# %% [markdown]
# ### Split features from labels
#
# Separate the target value, the "label", from the features. This label is the value that you will train the model to predict.

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('H')
test_labels = test_features.pop('H')

# %% [markdown]
# ## Normalization
#
# In the table of statistics it's easy to see how different the ranges of each feature are.

# %%
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#               mean       std
# H         1.747535  1.047002
# Temp     26.327279  4.359655
# P      1011.084426  6.154957
# Vm        6.649766  3.067025
# Vmsat     7.535785  3.547133

# %% [markdown]
# It is good practice to normalize features that use different scales and ranges.
#
# One reason this is important is because the features are multiplied by the model weights. So the scale of the outputs and the scale of the gradients are affected by the scale of the inputs.
#
# Although a model *might* converge without feature normalization, normalization makes training much more stable.

# %% [markdown]
# ### The Normalization layer
# The `preprocessing.Normalization` layer is a clean and simple way to build that preprocessing into your model.
#
# The first step is to create the layer:

# %%
normalizer = preprocessing.Normalization(axis=-1)

# %% [markdown]
# Then `.adapt()` it to the data:

# %%
normalizer.adapt(np.array(train_features))

# %% [markdown]
# This calculates the mean and variance, and stores them in the layer.

# %%
print(normalizer.mean.numpy())
# Out:
# [  26.327 1011.084    6.65     7.536]

# %% [markdown]
# When the layer is called it returns the input data, with each feature independently normalized:

# %%
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[  28.2  1012.1     6.6     7.34]]
#
# Normalized: [[ 0.43  0.17 -0.02 -0.05]]

# %% [markdown]
# ## Linear regression
#
# Before building a DNN model, start with a linear regression.

# %% [markdown]
# ### One Variable
#
# Start with a single-variable linear regression, to predict `H` from `Vmsat`.
#
# Training a model with `tf.keras` typically starts by defining the model architecture.
#
# In this case use a `keras.Sequential` model. This model represents a sequence of steps. In this case there are two steps:
#
# * Normalize the input `Vmsat`.
# * Apply a linear transformation ($y = mx+b$) to produce 1 output using `layers.Dense`.
#
# The number of _inputs_ can either be set by the `input_shape` argument, or automatically when the model is run for the first time.

# %% [markdown]
# First create the horsepower `Normalization` layer:

# %%
Vmsat = np.array(train_features['Vmsat'])

Vmsat_normalizer = preprocessing.Normalization(input_shape=[1,], axis=None)
Vmsat_normalizer.adapt(Vmsat)

# %% [markdown]
# Build the sequential model:

# %%
Vmsat_model = tf.keras.Sequential([
    Vmsat_normalizer,
    layers.Dense(units=1)
])

Vmsat_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_1 (Normalizati (None, 1)                 3
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 5
# Trainable params: 2
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# This model will predict `H` from `Vmsat`.
#
# Run the untrained model on the first 10 Vmsat values. The output won't be good, but you'll see that it has the expected shape, `(10,1)`:

# %%
Vmsat_model.predict(Vmsat[:10])
# Out:
# array([[-0.027],
#        [ 0.343],
#        [-0.689],
#        [-0.163],
#        [ 0.151],
#        [-0.032],
#        [ 0.357],
#        [ 0.934],
#        [ 0.04 ],
#        [-0.109]], dtype=float32)

# %% [markdown]
# Once the model is built, configure the training procedure using the `Model.compile()` method. The most important arguments to compile are the `loss` and the `optimizer` since these define what will be optimized (`mean_absolute_error`) and how (using the `optimizers.Adam`).

# %%
Vmsat_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %% [markdown]
# Once the training is configured, use `Model.fit()` to execute the training:

# %%
# %%time
history = Vmsat_model.fit(
    train_features['Vmsat'], train_labels,
    epochs=100,
    # suppress logging
    verbose=0,
    # Calculate validation results on 20% of the training data
    validation_split = 0.2)
# Out:
# CPU times: user 2min 23s, sys: 16min 48s, total: 19min 12s
# Wall time: 33.6 s

# %% [markdown]
# Visualize the model's training progress using the stats stored in the `history` object.

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  val_loss  epoch
# 95  0.462740  0.468392     95
# 96  0.463093  0.460494     96
# 97  0.461652  0.467219     97
# 98  0.460221  0.465195     98
# 99  0.461271  0.459542     99

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 1])
  plt.xlabel('Epoch')
  plt.ylabel('Error [H]')
  plt.legend()
  plt.grid(True)

# %%
plot_loss(history)

# %% [markdown]
# Collect the results on the test set, for later:

# %%
test_results = {}

test_results['Vmsat_model'] = Vmsat_model.evaluate(
    test_features['Vmsat'],
    test_labels, verbose=0)

# %% [markdown]
# Since this is a single variable regression it's easy to look at the model's predictions as a function of the input:

# %%
x = tf.linspace(0.0, 20, 251)
y = Vmsat_model.predict(x)

# %%
def plot_Vmsat(x, y):
  plt.scatter(train_features['Vmsat'], train_labels, label='Data')
  plt.plot(x, y, color='k', label='Predictions')
  plt.xlabel('Vmsat')
  plt.ylabel('H')
  plt.legend()

# %%
plt.figure(figsize=(10,6),dpi=200)
plot_Vmsat(x,y)

# %% [markdown]
# ### Multiple inputs

# %% [markdown]
# You can use an almost identical setup to make predictions based on multiple inputs. This model still does the same $y = mx+b$ except that $m$ is a matrix and $b$ is a vector.
#
# This time use the `Normalization` layer that was adapted to the whole dataset.

# %%
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

# %% [markdown]
# When you call this model on a batch of inputs, it produces `units=1` outputs for each example.

# %%
linear_model.predict(train_features[:10])
# Out:
# array([[ 0.36 ],
#        [-2.895],
#        [ 2.852],
#        [-1.02 ],
#        [-1.44 ],
#        [ 0.51 ],
#        [-2.741],
#        [-6.441],
#        [ 0.705],
#        [ 1.529]], dtype=float32)

# %% [markdown]
# When you call the model it's weight matrices will be built. Now you can see that the `kernel` (the $m$ in $y=mx+b$) has a shape of `(4,1)`.

# %%
linear_model.layers[1].kernel
# Out:
# <tf.Variable 'dense_1/kernel:0' shape=(4, 1) dtype=float32, numpy=
# array([[ 0.919],
#        [-0.635],
#        [-0.844],
#        [-1.036]], dtype=float32)>

# %% [markdown]
# Use the same `compile` and `fit` calls as for the single input `Vmsat` model:

# %%
linear_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_features, train_labels, 
    epochs=100,
    # suppress logging
    verbose=0,
    # Calculate validation results on 20% of the training data
    validation_split = 0.2)
# Out:
# CPU times: user 1min 58s, sys: 13min 32s, total: 15min 31s
# Wall time: 27.2 s

# %%
plot_loss(history)

# %%
test_results['linear_model'] = linear_model.evaluate(
    test_features, test_labels, verbose=0)

# %%
x = tf.linspace(0.0, 50, 251)
y = linear_model.predict(pd.DataFrame(x))

# %%
plot_Vmsat(x,y)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [H]']).T
# Out:
#               Mean absolute error [H]
# Vmsat_model                  0.469479
# linear_model                 0.489997

# %% [markdown]
# ## A DNN regression

# %% [markdown]
# The previous section implemented linear models for single and multiple inputs.
#
# This section implements single-input and multiple-input DNN models. The code is basically the same except the model is expanded to include some "hidden"  non-linear layers. The name "hidden" here just means not directly connected to the inputs or outputs.

# %% [markdown]
# These models will contain a few more layers than the linear model:
#
# * The normalization layer.
# * Two hidden, nonlinear, `Dense` layers using the `relu` nonlinearity.
# * A linear single-output layer.
#
# Both will use the same training procedure so the `compile` method is included in the `build_and_compile_model` function below.

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(64, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %% [markdown]
# ### One variable

# %% [markdown]
# Start with a DNN model for a single input: "Vmsat"

# %%
dnn_Vmsat_model = build_and_compile_model(Vmsat_normalizer)

# %% [markdown]
# This model has quite a few more trainable parameters than the linear models.

# %%
dnn_Vmsat_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_1 (Normalizati (None, 1)                 3
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,356
# Trainable params: 4,353
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Train the model:

# %%
# %%time
history = dnn_Vmsat_model.fit(
    train_features['Vmsat'], train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# CPU times: user 3min 36s, sys: 24min 19s, total: 27min 55s
# Wall time: 48.5 s

# %%
plot_loss(history)

# %%
x = tf.linspace(0.0, 20, 251)
y = dnn_Vmsat_model.predict(x)

# %%
plt.figure(figsize=(10,6),dpi=200)
plot_Vmsat(x,y)

# %%
test_results['dnn_Vmsat_model'] = dnn_Vmsat_model.evaluate(
    test_features['Vmsat'], test_labels,
    verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [H]']).T
# Out:
#                  Mean absolute error [H]
# Vmsat_model                     0.469479
# linear_model                    0.489997
# dnn_Vmsat_model                 0.429275

# %% [markdown]
# ### Full model

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization (Normalization (None, 4)                 9
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                320
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,554
# Trainable params: 4,545
# Non-trainable params: 9
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# CPU times: user 3min 52s, sys: 27min 8s, total: 31min
# Wall time: 53.4 s

# %%
plot_loss(history)

# %%
test_results['dnn_model'] = dnn_model.evaluate(test_features, test_labels, verbose=1)
# Out:
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3887

# %%
pd.DataFrame(test_results, index=['Mean absolute error [H]']).T
# Out:
#                  Mean absolute error [H]
# Vmsat_model                     0.469479
# linear_model                    0.489997
# dnn_Vmsat_model                 0.429275
# dnn_model                       0.388743

# %%
test_predictions = dnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [H]')
plt.ylabel('Predictions [H]')
lims = [0, 8]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [H]')
_ = plt.ylabel('Count')

# %%
plt.figure(figsize=(10,6),dpi=200)
x = tf.linspace(0.0, 25, 251)
#y1 = dnn_model.predict(x)
y2 = dnn_Vmsat_model.predict(pd.DataFrame(x))
y4 = Vmsat_model.predict(pd.DataFrame(x))

plt.scatter(train_features['Vmsat'], train_labels, label='Data',alpha=0.2)
#plt.plot(x, y1, color='b', label='DNN_multi')
#plt.plot(x, x, color='k')
plt.plot(x, y4, color='g', label='Linear')
plt.plot(x, y2, color='r', label='DNN')
plt.xlabel('Vmsat(m/s)')
plt.ylabel('H(m)')
plt.legend()

# %%
linear_model.save('saved_model/Vmsat_H_linear_model')
Vmsat_model.save(    'saved_model/Vmsat_H_Vm_model')
dnn_model.save(   'saved_model/Vmsat_H_ddn_model')
dnn_Vmsat_model.save('saved_model/Vmsat_H_ddn_Vm_model')
# Out:
# INFO:tensorflow:Assets written to: saved_model/Vmsat_H_linear_model/assets
# INFO:tensorflow:Assets written to: saved_model/Vmsat_H_Vm_model/assets
# INFO:tensorflow:Assets written to: saved_model/Vmsat_H_ddn_model/assets
# INFO:tensorflow:Assets written to: saved_model/Vmsat_H_ddn_Vm_model/assets

# %% [markdown]
# ## RNN

# %%
def build_and_compile_model_RNN(Norm):
  model = keras.Sequential([
      Norm,
      layers.SimpleRNN(64,  unroll=False, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
def build_and_compile_model_LSTM(Norm):
  model = keras.Sequential([
      Norm,
      layers.LSTM(64, input_shape=(1,1), activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
Vmsat_normalizer = preprocessing.Normalization(input_shape=[1,1], axis=None)
Vmsat_normalizer.adapt(Vmsat)

# %%
rnn_Vmsat_model = build_and_compile_model_RNN(Vmsat_normalizer)
#rnn_Vmsat_model = build_and_compile_model_LSTM(Vmsat_normalizer)

# %%
rnn_Vmsat_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_2 (Normalizati (None, 1, 1)              3
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 64)                4224
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,292
# Trainable params: 4,289
# Non-trainable params: 3
# _________________________________________________________________

# %%
train_features['Vmsat'],train_labels
# Out:
# (494916     7.342856
#  875391    10.004516
#  494639     2.574708
#  871520     6.362271
#  875427     8.620548
#              ...
#  867733     7.394600
#  504429     5.577857
#  503868     5.355890
#  864993     4.007861
#  875367    12.223137
#  Name: Vmsat, Length: 7262, dtype: float64,
#  494916    1.34
#  875391    1.76
#  494639    0.99
#  871520    1.59
#  875427    1.07
#            ...
#  867733    1.67
#  504429    1.37
#  503868    1.10
#  864993    0.64
#  875367    2.40
#  Name: H, Length: 7262, dtype: float64)

# %%
# %%time
history = rnn_Vmsat_model.fit(
    train_features['Vmsat'], train_labels,
    validation_split=0.2,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 182/182 [==============================] - 2s 4ms/step - loss: 1.2389 - val_loss: 0.4356
# Epoch 2/100
# 182/182 [==============================] - 0s 2ms/step - loss: 0.4269 - val_loss: 0.4282
# Epoch 3/100
# 182/182 [==============================] - 0s 2ms/step - loss: 0.4198 - val_loss: 0.4283
# Epoch 4/100
# 182/182 [==============================] - 0s 2ms/step - loss: 0.4300 - val_loss: 0.4280
# Epoch 5/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4272 - val_loss: 0.4279
# Epoch 6/100
# 182/182 [==============================] - 2s 13ms/step - loss: 0.4346 - val_loss: 0.4278
# Epoch 7/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4239 - val_loss: 0.4283
# Epoch 8/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4278 - val_loss: 0.4280
# Epoch 9/100
# 182/182 [==============================] - 0s 3ms/step - loss: 0.4194 - val_loss: 0.4301
# Epoch 10/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4268 - val_loss: 0.4278
# Epoch 11/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4294 - val_loss: 0.4278
# Epoch 12/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4233 - val_loss: 0.4308
# Epoch 13/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4244 - val_loss: 0.4283
# Epoch 14/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4298 - val_loss: 0.4297
# Epoch 15/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4249 - val_loss: 0.4317
# Epoch 16/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4206 - val_loss: 0.4283
# Epoch 17/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4248 - val_loss: 0.4279
# Epoch 18/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4290 - val_loss: 0.4285
# Epoch 19/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4193 - val_loss: 0.4287
# Epoch 20/100
# 182/182 [==============================] - 0s 2ms/step - loss: 0.4279 - val_loss: 0.4288
# Epoch 21/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4233 - val_loss: 0.4293
# Epoch 22/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4170 - val_loss: 0.4281
# Epoch 23/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4277 - val_loss: 0.4282
# Epoch 24/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4237 - val_loss: 0.4276
# Epoch 25/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4292 - val_loss: 0.4289
# Epoch 26/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4273 - val_loss: 0.4287
# Epoch 27/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4298 - val_loss: 0.4273
# Epoch 28/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4295 - val_loss: 0.4278
# Epoch 29/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4274 - val_loss: 0.4275
# Epoch 30/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4315 - val_loss: 0.4292
# Epoch 31/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4278 - val_loss: 0.4280
# Epoch 32/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4285 - val_loss: 0.4287
# Epoch 33/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4286 - val_loss: 0.4277
# Epoch 34/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4324 - val_loss: 0.4275
# Epoch 35/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4184 - val_loss: 0.4284
# Epoch 36/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4182 - val_loss: 0.4274
# Epoch 37/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4189 - val_loss: 0.4283
# Epoch 38/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4327 - val_loss: 0.4288
# Epoch 39/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4228 - val_loss: 0.4274
# Epoch 40/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4221 - val_loss: 0.4290
# Epoch 41/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4276 - val_loss: 0.4309
# Epoch 42/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4245 - val_loss: 0.4276
# Epoch 43/100
# 182/182 [==============================] - 0s 3ms/step - loss: 0.4280 - val_loss: 0.4279
# Epoch 44/100
# 182/182 [==============================] - 0s 3ms/step - loss: 0.4190 - val_loss: 0.4291
# Epoch 45/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4332 - val_loss: 0.4308
# Epoch 46/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4280 - val_loss: 0.4283
# Epoch 47/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4223 - val_loss: 0.4282
# Epoch 48/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4256 - val_loss: 0.4280
# Epoch 49/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4259 - val_loss: 0.4312
# Epoch 50/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4191 - val_loss: 0.4288
# Epoch 51/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4333 - val_loss: 0.4281
# Epoch 52/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4268 - val_loss: 0.4275
# Epoch 53/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.4270 - val_loss: 0.4300
# Epoch 54/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4280 - val_loss: 0.4281
# Epoch 55/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.4206 - val_loss: 0.4278
# Epoch 56/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4264 - val_loss: 0.4279
# Epoch 57/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4307 - val_loss: 0.4316
# Epoch 58/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4257 - val_loss: 0.4297
# Epoch 59/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4297 - val_loss: 0.4294
# Epoch 60/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4298 - val_loss: 0.4277
# Epoch 61/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4248 - val_loss: 0.4276
# Epoch 62/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4204 - val_loss: 0.4283
# Epoch 63/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4272 - val_loss: 0.4284
# Epoch 64/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4337 - val_loss: 0.4277
# Epoch 65/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.4314 - val_loss: 0.4284
# Epoch 66/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.4204 - val_loss: 0.4299
# Epoch 67/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.4188 - val_loss: 0.4294
# Epoch 68/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.4306 - val_loss: 0.4287
# Epoch 69/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4218 - val_loss: 0.4280
# Epoch 70/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.4224 - val_loss: 0.4289
# Epoch 71/100
# 182/182 [==============================] - 0s 3ms/step - loss: 0.4288 - val_loss: 0.4275
# Epoch 72/100
# 182/182 [==============================] - 0s 3ms/step - loss: 0.4278 - val_loss: 0.4286
# Epoch 73/100
# 182/182 [==============================] - 0s 3ms/step - loss: 0.4239 - val_loss: 0.4283
# Epoch 74/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.4264 - val_loss: 0.4279
# Epoch 75/100
# 182/182 [==============================] - 2s 8ms/step - loss: 0.4271 - val_loss: 0.4282
# Epoch 76/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4371 - val_loss: 0.4286
# Epoch 77/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.4245 - val_loss: 0.4294
# Epoch 78/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.4299 - val_loss: 0.4286
# Epoch 79/100
# 182/182 [==============================] - 0s 3ms/step - loss: 0.4204 - val_loss: 0.4278
# Epoch 80/100
# 182/182 [==============================] - 0s 3ms/step - loss: 0.4253 - val_loss: 0.4300
# Epoch 81/100
# 182/182 [==============================] - 0s 3ms/step - loss: 0.4236 - val_loss: 0.4288
# Epoch 82/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4299 - val_loss: 0.4282
# Epoch 83/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4213 - val_loss: 0.4284
# Epoch 84/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.4245 - val_loss: 0.4277
# Epoch 85/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.4192 - val_loss: 0.4283
# Epoch 86/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4216 - val_loss: 0.4284
# Epoch 87/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4287 - val_loss: 0.4278
# Epoch 88/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.4245 - val_loss: 0.4283
# Epoch 89/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.4302 - val_loss: 0.4298
# Epoch 90/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.4261 - val_loss: 0.4277
# Epoch 91/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.4261 - val_loss: 0.4294
# Epoch 92/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.4263 - val_loss: 0.4291
# Epoch 93/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.4285 - val_loss: 0.4286
# Epoch 94/100
# 182/182 [==============================] - 2s 10ms/step - loss: 0.4254 - val_loss: 0.4292
# Epoch 95/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.4244 - val_loss: 0.4281
# Epoch 96/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4229 - val_loss: 0.4285
# Epoch 97/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4301 - val_loss: 0.4316
# Epoch 98/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4179 - val_loss: 0.4286
# Epoch 99/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4252 - val_loss: 0.4288
# Epoch 100/100
# 182/182 [==============================] - 1s 3ms/step - loss: 0.4212 - val_loss: 0.4291
# CPU times: user 5min 29s, sys: 40min 17s, total: 45min 47s
# Wall time: 1min 19s

# %%
plot_loss(history)

# %%
test_results['rnn_Vmsat_model'] = rnn_Vmsat_model.evaluate(
    test_features['Vmsat'], test_labels,
    verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [H]']).T
# Out:
#                  Mean absolute error [H]
# Vmsat_model                     0.469479
# linear_model                    0.489997
# dnn_Vmsat_model                 0.429275
# dnn_model                       0.388743
# rnn_Vmsat_model                 0.428139

# %% [markdown]
# ### Multi-variable

# %%
normalizer = preprocessing.Normalization(input_shape=[4,1], axis=None)
normalizer.adapt(np.array(train_features))

# %%
rnn_model = build_and_compile_model_RNN(normalizer)
rnn_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_3 (Normalizati (None, 4, 1)              3
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 64)                4224
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,292
# Trainable params: 4,289
# Non-trainable params: 3
# _________________________________________________________________

# %%
# %%time
history = rnn_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 182/182 [==============================] - 2s 7ms/step - loss: 1.0012 - val_loss: 0.7811
# Epoch 2/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7790 - val_loss: 0.7875
# Epoch 3/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.7788 - val_loss: 0.7797
# Epoch 4/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.7641 - val_loss: 0.7810
# Epoch 5/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.7714 - val_loss: 0.7795
# Epoch 6/100
# 182/182 [==============================] - 4s 20ms/step - loss: 0.7704 - val_loss: 0.7790
# Epoch 7/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7730 - val_loss: 0.7784
# Epoch 8/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7778 - val_loss: 0.7801
# Epoch 9/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7794 - val_loss: 0.7783
# Epoch 10/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7806 - val_loss: 0.7800
# Epoch 11/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7763 - val_loss: 0.7769
# Epoch 12/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7686 - val_loss: 0.7779
# Epoch 13/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7664 - val_loss: 0.7820
# Epoch 14/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7729 - val_loss: 0.7759
# Epoch 15/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7733 - val_loss: 0.7749
# Epoch 16/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7758 - val_loss: 0.7742
# Epoch 17/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7790 - val_loss: 0.7807
# Epoch 18/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7778 - val_loss: 0.7886
# Epoch 19/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7739 - val_loss: 0.7768
# Epoch 20/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7669 - val_loss: 0.7711
# Epoch 21/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7832 - val_loss: 0.7746
# Epoch 22/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7607 - val_loss: 0.7690
# Epoch 23/100
# 182/182 [==============================] - 1s 4ms/step - loss: 0.7680 - val_loss: 0.7765
# Epoch 24/100
# 182/182 [==============================] - 1s 5ms/step - loss: 0.7640 - val_loss: 0.7673
# Epoch 25/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7620 - val_loss: 0.7694
# Epoch 26/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7398 - val_loss: 0.7676
# Epoch 27/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7710 - val_loss: 0.7683
# Epoch 28/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.7815 - val_loss: 0.7675
# Epoch 29/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7525 - val_loss: 0.7643
# Epoch 30/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7689 - val_loss: 0.7630
# Epoch 31/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7595 - val_loss: 0.7806
# Epoch 32/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7668 - val_loss: 0.7694
# Epoch 33/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7626 - val_loss: 0.7620
# Epoch 34/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7535 - val_loss: 0.7581
# Epoch 35/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7413 - val_loss: 0.7622
# Epoch 36/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7720 - val_loss: 0.7569
# Epoch 37/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7437 - val_loss: 0.7530
# Epoch 38/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7407 - val_loss: 0.7504
# Epoch 39/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7332 - val_loss: 0.7478
# Epoch 40/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7502 - val_loss: 0.7707
# Epoch 41/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7431 - val_loss: 0.7446
# Epoch 42/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7364 - val_loss: 0.7653
# Epoch 43/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7406 - val_loss: 0.7372
# Epoch 44/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7347 - val_loss: 0.7453
# Epoch 45/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7280 - val_loss: 0.7278
# Epoch 46/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7590 - val_loss: 0.7237
# Epoch 47/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7191 - val_loss: 0.8009
# Epoch 48/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7378 - val_loss: 0.7300
# Epoch 49/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.7194 - val_loss: 0.7383
# Epoch 50/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.7219 - val_loss: 0.7193
# Epoch 51/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.7084 - val_loss: 0.7093
# Epoch 52/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.7258 - val_loss: 0.7009
# Epoch 53/100
# 182/182 [==============================] - 2s 11ms/step - loss: 0.7002 - val_loss: 0.6994
# Epoch 54/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.6913 - val_loss: 0.6914
# Epoch 55/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.6928 - val_loss: 0.7040
# Epoch 56/100
# 182/182 [==============================] - 2s 13ms/step - loss: 0.6817 - val_loss: 0.7051
# Epoch 57/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.6909 - val_loss: 0.7015
# Epoch 58/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.6807 - val_loss: 0.6856
# Epoch 59/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.6755 - val_loss: 0.7144
# Epoch 60/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.6957 - val_loss: 0.6906
# Epoch 61/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.6955 - val_loss: 0.7031
# Epoch 62/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.6813 - val_loss: 0.7382
# Epoch 63/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.6845 - val_loss: 0.6924
# Epoch 64/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6760 - val_loss: 0.6690
# Epoch 65/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6813 - val_loss: 0.6716
# Epoch 66/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6671 - val_loss: 0.6604
# Epoch 67/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.6667 - val_loss: 0.6742
# Epoch 68/100
# 182/182 [==============================] - 5s 28ms/step - loss: 0.6496 - val_loss: 0.6654
# Epoch 69/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6485 - val_loss: 0.6491
# Epoch 70/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6747 - val_loss: 0.6564
# Epoch 71/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6473 - val_loss: 0.6575
# Epoch 72/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6378 - val_loss: 0.6365
# Epoch 73/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6374 - val_loss: 0.7052
# Epoch 74/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6750 - val_loss: 0.6554
# Epoch 75/100
# 182/182 [==============================] - 3s 19ms/step - loss: 0.6462 - val_loss: 0.6309
# Epoch 76/100
# 182/182 [==============================] - 3s 17ms/step - loss: 0.6227 - val_loss: 0.6527
# Epoch 77/100
# 182/182 [==============================] - 5s 25ms/step - loss: 0.6407 - val_loss: 0.6226
# Epoch 78/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6369 - val_loss: 0.6610
# Epoch 79/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6276 - val_loss: 0.6879
# Epoch 80/100
# 182/182 [==============================] - 2s 10ms/step - loss: 0.6406 - val_loss: 0.7107
# Epoch 81/100
# 182/182 [==============================] - 5s 30ms/step - loss: 0.6394 - val_loss: 0.6072
# Epoch 82/100
# 182/182 [==============================] - 3s 18ms/step - loss: 0.6244 - val_loss: 0.6059
# Epoch 83/100
# 182/182 [==============================] - 2s 10ms/step - loss: 0.6188 - val_loss: 0.6160
# Epoch 84/100
# 182/182 [==============================] - 2s 11ms/step - loss: 0.6053 - val_loss: 0.7618
# Epoch 85/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.6212 - val_loss: 0.6017
# Epoch 86/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.6073 - val_loss: 0.5988
# Epoch 87/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6300 - val_loss: 0.5928
# Epoch 88/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6018 - val_loss: 0.6158
# Epoch 89/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6129 - val_loss: 0.6095
# Epoch 90/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.6040 - val_loss: 0.5913
# Epoch 91/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.6196 - val_loss: 0.5855
# Epoch 92/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.6006 - val_loss: 0.5898
# Epoch 93/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6060 - val_loss: 0.6714
# Epoch 94/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6021 - val_loss: 0.5797
# Epoch 95/100
# 182/182 [==============================] - 2s 11ms/step - loss: 0.5828 - val_loss: 0.5823
# Epoch 96/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.5822 - val_loss: 0.6145
# Epoch 97/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.6055 - val_loss: 0.6759
# Epoch 98/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.5868 - val_loss: 0.5833
# Epoch 99/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.6221 - val_loss: 0.5831
# Epoch 100/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.5864 - val_loss: 0.5905
# CPU times: user 9min 34s, sys: 1h 12min 8s, total: 1h 21min 42s
# Wall time: 2min 20s

# %%
test_results['rnn_model'] = rnn_model.evaluate(
    test_features, test_labels,
    verbose=0)

# %%
plt.figure(figsize=(10,6),dpi=200)
x = tf.linspace(0.0, 25, 251)
y1 = rnn_Vmsat_model.predict(x)
y2 = dnn_Vmsat_model.predict(x)
y4 = Vmsat_model.predict(x)

plt.scatter(train_features['Vmsat'], train_labels, label='Data',alpha=0.2)
#plt.plot(x, y1, color='b', label='DNN_multi')
#plt.plot(x, x, color='k')
plt.plot(x, y4, color='g', label='Linear')
plt.plot(x, y2, color='r', label='DNN')
plt.plot(x, y1, color='b', label='RNN')
plt.xlabel('Vmsat(m/s)')
plt.ylabel('H(m)')
plt.legend()

# %%
test_predictions = rnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [H]')
plt.ylabel('Predictions [H]')
lims = [0, 8]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [H]')
_ = plt.ylabel('Count')

# %%
rnn_model.save(   'saved_model/Vmsat_H_rnn_model')
rnn_Vmsat_model.save('saved_model/Vmsat_H_rnn_Vm_model')
# Out:
# INFO:tensorflow:Assets written to: saved_model/Vmsat_H_rnn_model/assets
# INFO:tensorflow:Assets written to: saved_model/Vmsat_H_rnn_Vm_model/assets

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge

# %%
svr = GridSearchCV(SVR(kernel='rbf', gamma=0.1),
                   param_grid={"C": [1e0, 1e1, 1e2, 1e3],
                               "gamma": np.logspace(-2, 2, 5)})

kr = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1),
                  param_grid={"alpha": [1e0, 0.1, 1e-2, 1e-3],
                              "gamma": np.logspace(-2, 2, 5)})

# %%
history = svr.fit(np.array(train_features['Vmsat']).reshape(-1,1), train_labels)

# %%
train_sizes, train_scores_svr, test_scores_svr = learning_curve(
    svr,
    np.array(test_features['Vmsat']).reshape(-1,1),
    test_labels,
    train_sizes=np.linspace(0.1, 1, 10),
    scoring="neg_mean_absolute_error",
    cv=10,
)

# %%
#plt.plot(train_sizes, -test_scores_kr.mean(1), "o--", color="g", label="KRR")
plt.plot(train_sizes, -test_scores_svr.mean(1), "o--", color="r", label="SVR")
plt.xlabel("Train size")
plt.ylabel("Mean Absolute Error")
plt.title("Learning curves")
plt.legend(loc="best")

# %%
-test_scores_svr.mean(1)
# Out:
# array([0.503, 0.489, 0.455, 0.444, 0.45 , 0.439, 0.453, 0.451, 0.434,
#        0.436])

# %%
svr.predict(np.array(train_features['Vmsat']).reshape(-1,1))
# Out:
# array([1.428, 2.18 , 0.751, ..., 1.052, 0.878, 2.892])

# %% [markdown]
# ### Save model

# %%
import joblib
joblib.dump(svr, 'saved_model/Vmsat_H_svr_Vm_model')
# Out:
# ['saved_model/Vmsat_H_svr_Vm_model']

# %%
svr2 = joblib.load("saved_model/Vmsat_H_svr_Vm_model")

# %%
svr2.predict(np.array(train_features['Vmsat']).reshape(-1,1))
# Out:
# array([1.428, 2.18 , 0.751, ..., 1.052, 0.878, 2.892])

# %%
test_predictions = svr2.predict(np.asarray(test_features['Vmsat'])[:,None]).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Vmsat]')
plt.ylabel('Predictions [Vmsat]')
lims = [0, 15]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [Vmsat]')
_ = plt.ylabel('Count')

# %% [markdown]
# ## Multi-variable

# %%
history = svr.fit(np.array(train_features), train_labels)

# %%
train_sizes_mv, train_scores_svr_mv, test_scores_svr_mv = learning_curve(
    svr,
    np.array(test_features),
    test_labels,
    train_sizes=np.linspace(0.1, 1, 10),
    scoring="neg_mean_absolute_error",
    cv=10,
)

# %% [markdown]
# ### Save model

# %%
import joblib
joblib.dump(svr, 'saved_model/Vmsat_H_svr_model')
# Out:
# ['saved_model/Vmsat_H_svr_model']

# %%
svr = joblib.load("saved_model/Vmsat_H_svr_model")

# %%
svr.predict(np.array(train_features))
# Out:
# array([1.491, 2.162, 0.636, ..., 1.35 , 0.814, 2.652])

# %%
test_predictions = svr.predict(np.asarray(test_features)).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Vmsat]')
plt.ylabel('Predictions [Vmsat]')
lims = [0, 15]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [Vmsat]')
_ = plt.ylabel('Count')
