# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import sqlite3
import json

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# ## Read in data
#
# read in station name

# %%
df = pd.read_json('../ML_data_JJA.json')

# %% [markdown]
# ## clean data

# %%
from datetime import datetime
dataset = df[['STN','ST','DATETIME','H','Temp','P','Vm','Vmsat']]

df_index = (dataset['DATETIME']>datetime(2015,1,1,0)) & (dataset['DATETIME']<datetime(2020,1,1,0))
dataset = dataset[df_index]

#stnlist=['新竹浮標','龜山島浮標','臺東外洋浮標','龍洞浮標','小琉球浮標','花蓮浮標','東沙島浮標','馬祖浮標']
#stnlist=['東沙島浮標']
#stnlist=['新竹浮標','臺東外洋浮標','東沙島浮標','馬祖浮標']
stnlist=['臺東外洋浮標','東沙島浮標','馬祖浮標']

dataset = dataset[dataset['STN'].isin(stnlist)]
dataset = dataset.dropna()

# %%
dataset.isna().sum()
# Out:
# STN         0
# ST          0
# DATETIME    0
# H           0
# Temp        0
# P           0
# Vm          0
# Vmsat       0
# dtype: int64

# %% [markdown]
# Drop those rows to keep this initial tutorial simple.

# %%
dataset = dataset.dropna()
dataset.tail()
# Out:
#          STN     ST            DATETIME     H  Temp       P   Vm     Vmsat
# 874189  馬祖浮標  C6W08 2018-08-30 20:00:00  1.72  27.5  1011.3  7.1  8.688476
# 874195  馬祖浮標  C6W08 2018-08-31 02:00:00  1.33  27.5  1011.3  6.6  7.444074
# 874201  馬祖浮標  C6W08 2018-08-31 08:00:00  0.97  27.5  1012.3  5.8  7.620192
# 874207  馬祖浮標  C6W08 2018-08-31 14:00:00  0.91  27.5  1010.7  7.4  6.952201
# 874213  馬祖浮標  C6W08 2018-08-31 20:00:00  0.92  27.2  1011.7  6.8  8.044406

# %%
# %matplotlib inline
plt.figure(figsize=(16,8),dpi=200)
g = sns.FacetGrid(dataset, col="STN", col_wrap=2, height=3, aspect=3)
g.map(sns.lineplot, 'DATETIME','Vm',color='k')
g.map(sns.lineplot, 'DATETIME','Vmsat',color='r')
plt.legend(labels=['Buoy Wind','Satellite Wind'])

# %%
dataset.pop('DATETIME')
dataset.pop('ST')
dataset.pop('STN')
# Out:
# 151030    臺東外洋浮標
# 151036    臺東外洋浮標
# 151042    臺東外洋浮標
# 151048    臺東外洋浮標
# 151054    臺東外洋浮標
#            ...
# 874189      馬祖浮標
# 874195      馬祖浮標
# 874201      馬祖浮標
# 874207      馬祖浮標
# 874213      馬祖浮標
# Name: STN, Length: 2993, dtype: object

# %% [markdown]
# ### Split the data into train and test
#
# Now split the dataset into a training set and a test set.
#
# Use the test set in the final evaluation of your models.

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %% [markdown]
# ### Inspect the data
#
# Have a quick look at the joint distribution of a few pairs of columns from the training set.

# %%
sns.pairplot(train_dataset[['H', 'P', 'Temp', 'Vm','Vmsat']], diag_kind='kde')

# %% [markdown]
# Also look at the overall statistics, note how each feature covers a very different range:

# %%
train_dataset.describe().transpose()
# Out:
#         count         mean       std         min         25%          50%  \
# H      2394.0     1.400789  0.828046    0.230000     0.85000     1.225000
# Temp   2394.0    29.153926  2.052508   22.200000    28.30000    29.500000
# P      2394.0  1005.697536  3.849774  975.700000  1003.40000  1006.300000
# Vm     2394.0     5.594194  2.733343    1.100000     3.60000     5.300000
# Vmsat  2394.0     6.171065  3.194736    0.168848     4.05566     5.807255
#
#                75%          max
# H         1.740000    10.830000
# Temp     30.400000    34.100000
# P      1008.500000  1014.300000
# Vm        7.200000    26.800000
# Vmsat     7.870123    50.117094

# %% [markdown]
# ### Split features from labels
#
# Separate the target value, the "label", from the features. This label is the value that you will train the model to predict.

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('H')
test_labels = test_features.pop('H')

# %% [markdown]
# ## Normalization
#
# In the table of statistics it's easy to see how different the ranges of each feature are.

# %%
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#               mean       std
# H         1.400789  0.828046
# Temp     29.153926  2.052508
# P      1005.697536  3.849774
# Vm        5.594194  2.733343
# Vmsat     6.171065  3.194736

# %% [markdown]
# It is good practice to normalize features that use different scales and ranges.
#
# One reason this is important is because the features are multiplied by the model weights. So the scale of the outputs and the scale of the gradients are affected by the scale of the inputs.
#
# Although a model *might* converge without feature normalization, normalization makes training much more stable.

# %% [markdown]
# ### The Normalization layer
# The `preprocessing.Normalization` layer is a clean and simple way to build that preprocessing into your model.
#
# The first step is to create the layer:

# %%
normalizer = preprocessing.Normalization(axis=-1)

# %% [markdown]
# Then `.adapt()` it to the data:

# %%
normalizer.adapt(np.array(train_features))

# %% [markdown]
# This calculates the mean and variance, and stores them in the layer.

# %%
print(normalizer.mean.numpy())
# Out:
# [  29.154 1005.698    5.594    6.171]

# %% [markdown]
# When the layer is called it returns the input data, with each feature independently normalized:

# %%
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[  29.9 1008.4    3.6    4.3]]
#
# Normalized: [[ 0.36  0.7  -0.73 -0.59]]

# %% [markdown]
# ## Linear regression
#
# Before building a DNN model, start with a linear regression.

# %% [markdown]
# ### One Variable
#
# Start with a single-variable linear regression, to predict `H` from `Vmsat`.
#
# Training a model with `tf.keras` typically starts by defining the model architecture.
#
# In this case use a `keras.Sequential` model. This model represents a sequence of steps. In this case there are two steps:
#
# * Normalize the input `Vmsat`.
# * Apply a linear transformation ($y = mx+b$) to produce 1 output using `layers.Dense`.
#
# The number of _inputs_ can either be set by the `input_shape` argument, or automatically when the model is run for the first time.

# %% [markdown]
# First create the horsepower `Normalization` layer:

# %%
Vm = np.array(train_features['Vm'])

Vm_normalizer = preprocessing.Normalization(input_shape=[1,], axis=None)
Vm_normalizer.adapt(Vm)

# %% [markdown]
# Build the sequential model:

# %%
Vm_model = tf.keras.Sequential([
    Vm_normalizer,
    layers.Dense(units=1)
])

Vm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_1 (Normalizati (None, 1)                 3
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 5
# Trainable params: 2
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# This model will predict `H` from `Vms`.
#
# Run the untrained model on the first 10 Vm values. The output won't be good, but you'll see that it has the expected shape, `(10,1)`:

# %%
Vm_model.predict(Vm[:10])
# Out:
# array([[-0.767],
#        [ 1.963],
#        [-0.113],
#        [-0.267],
#        [-0.651],
#        [ 0.118],
#        [-1.036],
#        [ 1.04 ],
#        [-0.459],
#        [-1.19 ]], dtype=float32)

# %% [markdown]
# Once the model is built, configure the training procedure using the `Model.compile()` method. The most important arguments to compile are the `loss` and the `optimizer` since these define what will be optimized (`mean_absolute_error`) and how (using the `optimizers.Adam`).

# %%
Vm_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %% [markdown]
# Once the training is configured, use `Model.fit()` to execute the training:

# %%
# %%time
history = Vm_model.fit(
    train_features['Vm'], train_labels,
    epochs=100,
    # suppress logging
    verbose=0,
    # Calculate validation results on 20% of the training data
    validation_split = 0.2)
# Out:
# CPU times: user 1min 20s, sys: 10min 1s, total: 11min 21s
# Wall time: 20.2 s

# %% [markdown]
# Visualize the model's training progress using the stats stored in the `history` object.

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  val_loss  epoch
# 95  0.442505  0.456456     95
# 96  0.445207  0.459008     96
# 97  0.444020  0.456211     97
# 98  0.449571  0.488098     98
# 99  0.443196  0.461955     99

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 1])
  plt.xlabel('Epoch')
  plt.ylabel('Error [H]')
  plt.legend()
  plt.grid(True)

# %%
plot_loss(history)

# %% [markdown]
# Collect the results on the test set, for later:

# %%
test_results = {}

test_results['Vm_model'] = Vm_model.evaluate(
    test_features['Vm'],
    test_labels, verbose=0)

# %% [markdown]
# Since this is a single variable regression it's easy to look at the model's predictions as a function of the input:

# %%
x = tf.linspace(0.0, 20, 251)
y = Vm_model.predict(x)

# %%
def plot_Vm(x, y):
  plt.scatter(train_features['Vm'], train_labels, label='Data')
  plt.plot(x, y, color='k', label='Predictions')
  plt.xlabel('Vm')
  plt.ylabel('H')
  plt.legend()

# %%
plt.figure(figsize=(10,6),dpi=200)
plot_Vm(x,y)

# %% [markdown]
# ### Multiple inputs

# %% [markdown]
# You can use an almost identical setup to make predictions based on multiple inputs. This model still does the same $y = mx+b$ except that $m$ is a matrix and $b$ is a vector.
#
# This time use the `Normalization` layer that was adapted to the whole dataset.

# %%
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

# %% [markdown]
# When you call this model on a batch of inputs, it produces `units=1` outputs for each example.

# %%
linear_model.predict(train_features[:10])
# Out:
# array([[-0.619],
#        [ 1.777],
#        [-0.509],
#        [ 0.629],
#        [ 0.659],
#        [-1.215],
#        [ 1.376],
#        [-0.188],
#        [ 0.197],
#        [-0.435]], dtype=float32)

# %% [markdown]
# When you call the model it's weight matrices will be built. Now you can see that the `kernel` (the $m$ in $y=mx+b$) has a shape of `(4,1)`.

# %%
linear_model.layers[1].kernel
# Out:
# <tf.Variable 'dense_1/kernel:0' shape=(4, 1) dtype=float32, numpy=
# array([[ 0.424],
#        [-0.784],
#        [ 0.561],
#        [-0.318]], dtype=float32)>

# %% [markdown]
# Use the same `compile` and `fit` calls as for the single input `Vmsat` model:

# %%
linear_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_features, train_labels, 
    epochs=100,
    # suppress logging
    verbose=0,
    # Calculate validation results on 20% of the training data
    validation_split = 0.2)
# Out:
# CPU times: user 1min 19s, sys: 9min 45s, total: 11min 5s
# Wall time: 19.4 s

# %%
plot_loss(history)

# %%
test_results['linear_model'] = linear_model.evaluate(
    test_features, test_labels, verbose=0)

# %%
x = tf.linspace(0.0, 50, 251)
y = linear_model.predict(pd.DataFrame(x))

# %%
plot_Vm(x,y)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [H]']).T
# Out:
#               Mean absolute error [H]
# Vm_model                     0.443485
# linear_model                 0.401784

# %% [markdown]
# ## A DNN regression

# %% [markdown]
# The previous section implemented linear models for single and multiple inputs.
#
# This section implements single-input and multiple-input DNN models. The code is basically the same except the model is expanded to include some "hidden"  non-linear layers. The name "hidden" here just means not directly connected to the inputs or outputs.

# %% [markdown]
# These models will contain a few more layers than the linear model:
#
# * The normalization layer.
# * Two hidden, nonlinear, `Dense` layers using the `relu` nonlinearity.
# * A linear single-output layer.
#
# Both will use the same training procedure so the `compile` method is included in the `build_and_compile_model` function below.

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(64, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %% [markdown]
# ### One variable

# %% [markdown]
# Start with a DNN model for a single input: "Vmsat"

# %%
dnn_Vm_model = build_and_compile_model(Vm_normalizer)

# %% [markdown]
# This model has quite a few more trainable parameters than the linear models.

# %%
dnn_Vm_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_1 (Normalizati (None, 1)                 3
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,356
# Trainable params: 4,353
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Train the model:

# %%
# %%time
history = dnn_Vm_model.fit(
    train_features['Vm'], train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# CPU times: user 1min 58s, sys: 15min 48s, total: 17min 46s
# Wall time: 39.6 s

# %%
plot_loss(history)

# %%
x = tf.linspace(0.0, 20, 251)
y = dnn_Vm_model.predict(x)

# %%
plt.figure(figsize=(10,6),dpi=200)
plot_Vm(x,y)

# %%
test_results['dnn_Vm_model'] = dnn_Vm_model.evaluate(
    test_features['Vm'], test_labels,
    verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [H]']).T
# Out:
#               Mean absolute error [H]
# Vm_model                     0.443485
# linear_model                 0.401784
# dnn_Vm_model                 0.426562

# %% [markdown]
# ### Full model

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization (Normalization (None, 4)                 9
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                320
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,554
# Trainable params: 4,545
# Non-trainable params: 9
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# CPU times: user 1min 21s, sys: 11min 37s, total: 12min 58s
# Wall time: 38.4 s

# %%
plot_loss(history)

# %%
test_results['dnn_model'] = dnn_model.evaluate(test_features, test_labels, verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [H]']).T
# Out:
#               Mean absolute error [H]
# Vm_model                     0.443485
# linear_model                 0.401784
# dnn_Vm_model                 0.426562
# dnn_model                    0.317888

# %%
test_predictions = dnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [H]')
plt.ylabel('Predictions [H]')
lims = [0, 8]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [H]')
_ = plt.ylabel('Count')

# %%
plt.figure(figsize=(10,6),dpi=200)
x = tf.linspace(0.0, 25, 251)
#y1 = dnn_model.predict(x)
y2 = dnn_Vm_model.predict(x)
y4 = Vm_model.predict(x)

plt.scatter(train_features['Vm'], train_labels, label='Data',alpha=0.2)
#plt.plot(x, y1, color='b', label='DNN_multi')
#plt.plot(x, x, color='k')
plt.plot(x, y4, color='g', label='Linear')
plt.plot(x, y2, color='r', label='DNN')
plt.xlabel('Vm(m/s)')
plt.ylabel('H(m)')
plt.legend()

# %%
# !mkdir -p saved_model

# %%
linear_model.save('saved_model/Vm_H_linear_model_JJA')
Vm_model.save(    'saved_model/Vm_H_Vm_model_JJA')
dnn_model.save(   'saved_model/Vm_H_dnn_model_JJA')
dnn_Vm_model.save('saved_model/Vm_H_dnn_Vm_model_JJA')
# Out:
# INFO:tensorflow:Assets written to: saved_model/Vm_H_linear_model_JJA/assets
# INFO:tensorflow:Assets written to: saved_model/Vm_H_Vm_model_JJA/assets
# INFO:tensorflow:Assets written to: saved_model/Vm_H_dnn_model_JJA/assets
# INFO:tensorflow:Assets written to: saved_model/Vm_H_dnn_Vm_model_JJA/assets

# %% [markdown]
# # RNN

# %%
def build_and_compile_model_RNN(Norm):
  model = keras.Sequential([
      Norm,
      layers.SimpleRNN(64,  unroll=False, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
def build_and_compile_model_LSTM(Norm):
  model = keras.Sequential([
      Norm,
      layers.LSTM(64, input_shape=(1,1), activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
Vm_normalizer = preprocessing.Normalization(input_shape=[1,1], axis=None)
Vm_normalizer.adapt(Vm)

# %%
rnn_Vm_model = build_and_compile_model_RNN(Vm_normalizer)
#rnn_Vm_model = build_and_compile_model_LSTM(Vmsat_normalizer)

# %%
rnn_Vm_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_2 (Normalizati (None, 1, 1)              3
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 64)                4224
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,292
# Trainable params: 4,289
# Non-trainable params: 3
# _________________________________________________________________

# %%
train_features['Vm'],train_labels
# Out:
# (495712     3.6
#  503049    10.7
#  496247     5.3
#  504047     4.9
#  503061     3.9
#            ...
#  497234     4.3
#  155785     5.7
#  151318     3.5
#  492453     2.4
#  872579     7.7
#  Name: Vm, Length: 2394, dtype: float64,
#  495712    0.83
#  503049    3.23
#  496247    0.93
#  504047    1.48
#  503061    1.85
#            ...
#  497234    1.96
#  155785    0.92
#  151318    1.55
#  492453    0.80
#  872579    0.88
#  Name: H, Length: 2394, dtype: float64)

# %%
# %%time
history = rnn_Vm_model.fit(
    train_features['Vm'], train_labels,
    validation_split=0.2,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 3s 20ms/step - loss: 1.2829 - val_loss: 0.7097
# Epoch 2/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.6214 - val_loss: 0.4657
# Epoch 3/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4306 - val_loss: 0.4485
# Epoch 4/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4307 - val_loss: 0.4438
# Epoch 5/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4200 - val_loss: 0.4428
# Epoch 6/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4272 - val_loss: 0.4423
# Epoch 7/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4268 - val_loss: 0.4396
# Epoch 8/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4264 - val_loss: 0.4404
# Epoch 9/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4138 - val_loss: 0.4412
# Epoch 10/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4215 - val_loss: 0.4399
# Epoch 11/100
# 60/60 [==============================] - 0s 5ms/step - loss: 0.4307 - val_loss: 0.4397
# Epoch 12/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4171 - val_loss: 0.4445
# Epoch 13/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4234 - val_loss: 0.4397
# Epoch 14/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4100 - val_loss: 0.4395
# Epoch 15/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4311 - val_loss: 0.4392
# Epoch 16/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4109 - val_loss: 0.4404
# Epoch 17/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4258 - val_loss: 0.4426
# Epoch 18/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4160 - val_loss: 0.4398
# Epoch 19/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4195 - val_loss: 0.4398
# Epoch 20/100
# 60/60 [==============================] - 0s 5ms/step - loss: 0.4111 - val_loss: 0.4401
# Epoch 21/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4190 - val_loss: 0.4403
# Epoch 22/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4238 - val_loss: 0.4389
# Epoch 23/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4317 - val_loss: 0.4388
# Epoch 24/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4115 - val_loss: 0.4383
# Epoch 25/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4172 - val_loss: 0.4388
# Epoch 26/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4288 - val_loss: 0.4377
# Epoch 27/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4148 - val_loss: 0.4402
# Epoch 28/100
# 60/60 [==============================] - 0s 5ms/step - loss: 0.4369 - val_loss: 0.4403
# Epoch 29/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4148 - val_loss: 0.4408
# Epoch 30/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4082 - val_loss: 0.4382
# Epoch 31/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4149 - val_loss: 0.4380
# Epoch 32/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4024 - val_loss: 0.4380
# Epoch 33/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4092 - val_loss: 0.4377
# Epoch 34/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4294 - val_loss: 0.4399
# Epoch 35/100
# 60/60 [==============================] - 0s 4ms/step - loss: 0.4153 - val_loss: 0.4374
# Epoch 36/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4084 - val_loss: 0.4384
# Epoch 37/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4196 - val_loss: 0.4386
# Epoch 38/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4089 - val_loss: 0.4376
# Epoch 39/100
# 60/60 [==============================] - 0s 4ms/step - loss: 0.4161 - val_loss: 0.4384
# Epoch 40/100
# 60/60 [==============================] - 0s 5ms/step - loss: 0.4137 - val_loss: 0.4396
# Epoch 41/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4218 - val_loss: 0.4378
# Epoch 42/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4138 - val_loss: 0.4385
# Epoch 43/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.3967 - val_loss: 0.4375
# Epoch 44/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.4272 - val_loss: 0.4373
# Epoch 45/100
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4120 - val_loss: 0.4387
# Epoch 46/100
# 60/60 [==============================] - 0s 5ms/step - loss: 0.4219 - val_loss: 0.4380
# Epoch 47/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.4032 - val_loss: 0.4371
# Epoch 48/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4232 - val_loss: 0.4394
# Epoch 49/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4345 - val_loss: 0.4372
# Epoch 50/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4172 - val_loss: 0.4382
# Epoch 51/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4258 - val_loss: 0.4367
# Epoch 52/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.4120 - val_loss: 0.4378
# Epoch 53/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4149 - val_loss: 0.4364
# Epoch 54/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4185 - val_loss: 0.4387
# Epoch 55/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4325 - val_loss: 0.4368
# Epoch 56/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.4026 - val_loss: 0.4389
# Epoch 57/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4189 - val_loss: 0.4379
# Epoch 58/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.4231 - val_loss: 0.4371
# Epoch 59/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4070 - val_loss: 0.4398
# Epoch 60/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4140 - val_loss: 0.4362
# Epoch 61/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4093 - val_loss: 0.4372
# Epoch 62/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4217 - val_loss: 0.4365
# Epoch 63/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4159 - val_loss: 0.4372
# Epoch 64/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4211 - val_loss: 0.4365
# Epoch 65/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4121 - val_loss: 0.4367
# Epoch 66/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.4307 - val_loss: 0.4366
# Epoch 67/100
# 60/60 [==============================] - 1s 8ms/step - loss: 0.4122 - val_loss: 0.4372
# Epoch 68/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4049 - val_loss: 0.4361
# Epoch 69/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.4006 - val_loss: 0.4370
# Epoch 70/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.4187 - val_loss: 0.4356
# Epoch 71/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4268 - val_loss: 0.4352
# Epoch 72/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4212 - val_loss: 0.4353
# Epoch 73/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4072 - val_loss: 0.4367
# Epoch 74/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4165 - val_loss: 0.4355
# Epoch 75/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4204 - val_loss: 0.4363
# Epoch 76/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4047 - val_loss: 0.4356
# Epoch 77/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4282 - val_loss: 0.4389
# Epoch 78/100
# 60/60 [==============================] - 1s 8ms/step - loss: 0.4199 - val_loss: 0.4348
# Epoch 79/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4110 - val_loss: 0.4348
# Epoch 80/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4001 - val_loss: 0.4351
# Epoch 81/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.4197 - val_loss: 0.4356
# Epoch 82/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4213 - val_loss: 0.4364
# Epoch 83/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.4235 - val_loss: 0.4348
# Epoch 84/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4017 - val_loss: 0.4350
# Epoch 85/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4015 - val_loss: 0.4356
# Epoch 86/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4045 - val_loss: 0.4356
# Epoch 87/100
# 60/60 [==============================] - 1s 8ms/step - loss: 0.4141 - val_loss: 0.4359
# Epoch 88/100
# 60/60 [==============================] - 0s 5ms/step - loss: 0.4144 - val_loss: 0.4346
# Epoch 89/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4210 - val_loss: 0.4359
# Epoch 90/100
# 60/60 [==============================] - 0s 5ms/step - loss: 0.4199 - val_loss: 0.4345
# Epoch 91/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.4275 - val_loss: 0.4341
# Epoch 92/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.4029 - val_loss: 0.4347
# Epoch 93/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4019 - val_loss: 0.4344
# Epoch 94/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4106 - val_loss: 0.4340
# Epoch 95/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.4242 - val_loss: 0.4377
# Epoch 96/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4208 - val_loss: 0.4347
# Epoch 97/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.4214 - val_loss: 0.4357
# Epoch 98/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.4042 - val_loss: 0.4373
# Epoch 99/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.4071 - val_loss: 0.4347
# Epoch 100/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4110 - val_loss: 0.4338
# CPU times: user 1min 26s, sys: 11min 53s, total: 13min 19s
# Wall time: 53.7 s

# %%
plot_loss(history)

# %%
test_results['rnn_Vm_model'] = rnn_Vm_model.evaluate(
    test_features['Vm'], test_labels,
    verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [H]']).T
# Out:
#               Mean absolute error [H]
# Vm_model                     0.443485
# linear_model                 0.401784
# dnn_Vm_model                 0.426562
# dnn_model                    0.317888
# rnn_Vm_model                 0.422815

# %% [markdown]
# ### Multi-variable

# %%
normalizer = preprocessing.Normalization(input_shape=[4,1], axis=None)
normalizer.adapt(np.array(train_features))

# %%
rnn_model = build_and_compile_model_RNN(normalizer)
rnn_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_3 (Normalizati (None, 4, 1)              3
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 64)                4224
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,292
# Trainable params: 4,289
# Non-trainable params: 3
# _________________________________________________________________

# %%
# %%time
history = rnn_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 4s 26ms/step - loss: 1.0544 - val_loss: 0.5689
# Epoch 2/100
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5496 - val_loss: 0.5674
# Epoch 3/100
# 60/60 [==============================] - 1s 21ms/step - loss: 0.5806 - val_loss: 0.5656
# Epoch 4/100
# 60/60 [==============================] - 1s 22ms/step - loss: 0.5721 - val_loss: 0.5787
# Epoch 5/100
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5843 - val_loss: 0.5659
# Epoch 6/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5728 - val_loss: 0.5682
# Epoch 7/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5507 - val_loss: 0.5660
# Epoch 8/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5696 - val_loss: 0.5654
# Epoch 9/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.5520 - val_loss: 0.5750
# Epoch 10/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.5703 - val_loss: 0.5771
# Epoch 11/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5805 - val_loss: 0.5759
# Epoch 12/100
# 60/60 [==============================] - 1s 19ms/step - loss: 0.5780 - val_loss: 0.5667
# Epoch 13/100
# 60/60 [==============================] - 1s 19ms/step - loss: 0.5654 - val_loss: 0.5660
# Epoch 14/100
# 60/60 [==============================] - 1s 20ms/step - loss: 0.5828 - val_loss: 0.5657
# Epoch 15/100
# 60/60 [==============================] - 1s 19ms/step - loss: 0.5452 - val_loss: 0.5658
# Epoch 16/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5894 - val_loss: 0.5695
# Epoch 17/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5981 - val_loss: 0.5651
# Epoch 18/100
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5843 - val_loss: 0.5661
# Epoch 19/100
# 60/60 [==============================] - 1s 24ms/step - loss: 0.5623 - val_loss: 0.5668
# Epoch 20/100
# 60/60 [==============================] - 1s 23ms/step - loss: 0.5476 - val_loss: 0.5688
# Epoch 21/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5795 - val_loss: 0.5651
# Epoch 22/100
# 60/60 [==============================] - 1s 19ms/step - loss: 0.5646 - val_loss: 0.5649
# Epoch 23/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5737 - val_loss: 0.5649
# Epoch 24/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.5692 - val_loss: 0.5669
# Epoch 25/100
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5959 - val_loss: 0.5689
# Epoch 26/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.6002 - val_loss: 0.5657
# Epoch 27/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5668 - val_loss: 0.5647
# Epoch 28/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5459 - val_loss: 0.5671
# Epoch 29/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5765 - val_loss: 0.5647
# Epoch 30/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5701 - val_loss: 0.5651
# Epoch 31/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5905 - val_loss: 0.5686
# Epoch 32/100
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5703 - val_loss: 0.5670
# Epoch 33/100
# 60/60 [==============================] - 1s 20ms/step - loss: 0.5899 - val_loss: 0.5702
# Epoch 34/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5510 - val_loss: 0.5685
# Epoch 35/100
# 60/60 [==============================] - 1s 25ms/step - loss: 0.5626 - val_loss: 0.5658
# Epoch 36/100
# 60/60 [==============================] - 1s 22ms/step - loss: 0.5959 - val_loss: 0.5669
# Epoch 37/100
# 60/60 [==============================] - 1s 20ms/step - loss: 0.5653 - val_loss: 0.5668
# Epoch 38/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5828 - val_loss: 0.5678
# Epoch 39/100
# 60/60 [==============================] - 1s 21ms/step - loss: 0.5548 - val_loss: 0.5678
# Epoch 40/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5654 - val_loss: 0.5688
# Epoch 41/100
# 60/60 [==============================] - 1s 20ms/step - loss: 0.5554 - val_loss: 0.5644
# Epoch 42/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5774 - val_loss: 0.5645
# Epoch 43/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5792 - val_loss: 0.5646
# Epoch 44/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5679 - val_loss: 0.5642
# Epoch 45/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.5721 - val_loss: 0.5705
# Epoch 46/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5909 - val_loss: 0.5643
# Epoch 47/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.5617 - val_loss: 0.5648
# Epoch 48/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5783 - val_loss: 0.5709
# Epoch 49/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5747 - val_loss: 0.5741
# Epoch 50/100
# 60/60 [==============================] - 1s 22ms/step - loss: 0.5700 - val_loss: 0.5705
# Epoch 51/100
# 60/60 [==============================] - 1s 22ms/step - loss: 0.5949 - val_loss: 0.5651
# Epoch 52/100
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5575 - val_loss: 0.5643
# Epoch 53/100
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5738 - val_loss: 0.5638
# Epoch 54/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5690 - val_loss: 0.5648
# Epoch 55/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5763 - val_loss: 0.5722
# Epoch 56/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5754 - val_loss: 0.5661
# Epoch 57/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5661 - val_loss: 0.5638
# Epoch 58/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5935 - val_loss: 0.5650
# Epoch 59/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5504 - val_loss: 0.5674
# Epoch 60/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5694 - val_loss: 0.5656
# Epoch 61/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5554 - val_loss: 0.5650
# Epoch 62/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.5500 - val_loss: 0.5639
# Epoch 63/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.5630 - val_loss: 0.5681
# Epoch 64/100
# 60/60 [==============================] - 1s 19ms/step - loss: 0.5582 - val_loss: 0.5673
# Epoch 65/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.5933 - val_loss: 0.5718
# Epoch 66/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.5988 - val_loss: 0.5630
# Epoch 67/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.5850 - val_loss: 0.5630
# Epoch 68/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5897 - val_loss: 0.5650
# Epoch 69/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5727 - val_loss: 0.5643
# Epoch 70/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5879 - val_loss: 0.5627
# Epoch 71/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.5556 - val_loss: 0.5625
# Epoch 72/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5545 - val_loss: 0.5669
# Epoch 73/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.5713 - val_loss: 0.5628
# Epoch 74/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5821 - val_loss: 0.5628
# Epoch 75/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5825 - val_loss: 0.5688
# Epoch 76/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.5881 - val_loss: 0.5645
# Epoch 77/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.5685 - val_loss: 0.5686
# Epoch 78/100
# 60/60 [==============================] - 0s 7ms/step - loss: 0.5546 - val_loss: 0.5626
# Epoch 79/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5659 - val_loss: 0.5620
# Epoch 80/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5755 - val_loss: 0.5638
# Epoch 81/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.5818 - val_loss: 0.5619
# Epoch 82/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.5642 - val_loss: 0.5617
# Epoch 83/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5798 - val_loss: 0.5615
# Epoch 84/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5749 - val_loss: 0.5644
# Epoch 85/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.5601 - val_loss: 0.5613
# Epoch 86/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5658 - val_loss: 0.5610
# Epoch 87/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5697 - val_loss: 0.5616
# Epoch 88/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.5835 - val_loss: 0.5638
# Epoch 89/100
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5457 - val_loss: 0.5629
# Epoch 90/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5470 - val_loss: 0.5611
# Epoch 91/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5698 - val_loss: 0.5603
# Epoch 92/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.5521 - val_loss: 0.5603
# Epoch 93/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5676 - val_loss: 0.5600
# Epoch 94/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5432 - val_loss: 0.5605
# Epoch 95/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.5704 - val_loss: 0.5686
# Epoch 96/100
# 60/60 [==============================] - 1s 19ms/step - loss: 0.5492 - val_loss: 0.5611
# Epoch 97/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5806 - val_loss: 0.5649
# Epoch 98/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.5572 - val_loss: 0.5629
# Epoch 99/100
# 60/60 [==============================] - 1s 21ms/step - loss: 0.5827 - val_loss: 0.5614
# Epoch 100/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.5445 - val_loss: 0.5605
# CPU times: user 2min 26s, sys: 20min 10s, total: 22min 37s
# Wall time: 1min 35s

# %%
test_results['rnn_model'] = rnn_model.evaluate(
    test_features, test_labels,
    verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [H]']).T
# Out:
#               Mean absolute error [H]
# Vm_model                     0.443485
# linear_model                 0.401784
# dnn_Vm_model                 0.426562
# dnn_model                    0.317888
# rnn_Vm_model                 0.422815
# rnn_model                    0.536459

# %%
plt.figure(figsize=(10,6),dpi=200)
x = tf.linspace(0.0, 25, 251)
y1 = rnn_Vm_model.predict(x)
y2 = dnn_Vm_model.predict(x)
y4 = Vm_model.predict(x)

plt.scatter(train_features['Vm'], train_labels, label='Data',alpha=0.2)
#plt.plot(x, y1, color='b', label='DNN_multi')
#plt.plot(x, x, color='k')
plt.plot(x, y4, color='g', label='Linear')
plt.plot(x, y2, color='r', label='DNN')
plt.plot(x, y1, color='b', label='RNN')
plt.xlabel('Vm(m/s)')
plt.ylabel('H(m)')
plt.legend()

# %%
test_predictions = rnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [H]')
plt.ylabel('Predictions [H]')
lims = [0, 8]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [H]')
_ = plt.ylabel('Count')

# %%
rnn_model.save(   'saved_model/Vm_H_rnn_model_JJA')
rnn_Vm_model.save('saved_model/Vm_H_rnn_Vm_model_JJA')
# Out:
# INFO:tensorflow:Assets written to: saved_model/Vm_H_rnn_model_JJA/assets
# INFO:tensorflow:Assets written to: saved_model/Vm_H_rnn_Vm_model_JJA/assets

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge

# %%
svr = GridSearchCV(SVR(kernel='rbf', gamma=0.1),
                   param_grid={"C": [1e0, 1e1, 1e2, 1e3],
                               "gamma": np.logspace(-2, 2, 5)})

kr = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1),
                  param_grid={"alpha": [1e0, 0.1, 1e-2, 1e-3],
                              "gamma": np.logspace(-2, 2, 5)})

# %%
history = svr.fit(np.array(train_features['Vm']).reshape(-1,1), train_labels)

# %%
train_sizes, train_scores_svr, test_scores_svr = learning_curve(
    svr,
    np.array(test_features['Vm']).reshape(-1,1),
    test_labels,
    train_sizes=np.linspace(0.1, 1, 10),
    scoring="neg_mean_absolute_error",
    cv=10,
)

# %%
#plt.plot(train_sizes, -test_scores_kr.mean(1), "o--", color="g", label="KRR")
plt.plot(train_sizes, -test_scores_svr.mean(1), "o--", color="r", label="SVR")
plt.xlabel("Train size")
plt.ylabel("Mean Absolute Error")
plt.title("Learning curves")
plt.legend(loc="best")

# %%
-test_scores_svr.mean(1)
# Out:
# array([0.476, 0.439, 0.453, 0.447, 0.437, 0.434, 0.444, 0.433, 0.433,
#        0.43 ])

# %%
svr.predict(np.array(train_features['Vm']).reshape(-1,1))
# Out:
# array([0.918, 2.407, 1.135, ..., 0.908, 0.836, 1.596])

# %%
import joblib
joblib.dump(svr, 'saved_model/Vm_H_svr_Vm_model_JJA')
# Out:
# ['saved_model/Vm_H_svr_Vm_model_JJA']

# %%
svr2 = joblib.load("saved_model/Vm_H_svr_Vm_model_JJA")

# %%
svr2.predict(np.array(train_features['Vm']).reshape(-1,1))
# Out:
# array([0.918, 2.407, 1.135, ..., 0.908, 0.836, 1.596])

# %%
test_predictions = svr2.predict(np.asarray(test_features['Vm'])[:,None]).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Vm]')
plt.ylabel('Predictions [Vm]')
lims = [0, 15]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [Vm]')
_ = plt.ylabel('Count')

# %% [markdown]
# ## Multi-variable

# %%
history = svr.fit(np.array(train_features), train_labels)

# %%
train_sizes_mv, train_scores_svr_mv, test_scores_svr_mv = learning_curve(
    svr,
    np.array(test_features),
    test_labels,
    train_sizes=np.linspace(0.1, 1, 10),
    scoring="neg_mean_absolute_error",
    cv=10,
)

# %%
import joblib
joblib.dump(svr, 'saved_model/Vm_H_svr_model_JJA')
# Out:
# ['saved_model/Vm_H_svr_model_JJA']

# %%
svr = joblib.load("saved_model/Vm_H_svr_model_JJA")

# %%
svr.predict(np.array(train_features))
# Out:
# array([0.835, 3.117, 0.909, ..., 0.894, 0.733, 1.452])

# %%
test_predictions = svr.predict(np.asarray(test_features)).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Vm]')
plt.ylabel('Predictions [Vm]')
lims = [0, 15]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [Vm]')
_ = plt.ylabel('Count')

# %%
def svr_evaluate(test_features, test_labels):
    return np.mean(np.abs(test_features-test_labels))

# %%
svr_evaluate(svr.predict(np.array(test_features)),np.array(test_labels))
# Out:
# 0.3200038593029601

# %%
np.abs(svr.predict(np.array(test_features))-np.array(test_labels))
# Out:
# array([0.227, 0.587, 0.794, 0.05 , 0.183, 0.307, 0.077, 0.07 , 0.372,
#        0.06 , 0.109, 0.318, 0.071, 0.031, 0.116, 0.065, 0.205, 0.21 ,
#        0.032, 0.053, 0.106, 0.086, 0.045, 0.157, 0.168, 0.166, 0.061,
#        0.247, 0.026, 0.236, 0.086, 0.074, 0.029, 0.103, 0.112, 0.023,
#        0.234, 0.736, 0.119, 0.093, 0.001, 0.009, 0.209, 0.266, 0.223,
#        0.213, 0.291, 0.392, 0.351, 0.319, 0.23 , 0.367, 1.043, 0.007,
#        0.254, 0.55 , 0.284, 0.024, 0.02 , 0.19 , 0.48 , 0.417, 0.552,
#        0.456, 0.042, 0.545, 0.29 , 0.015, 0.205, 0.362, 0.028, 0.049,
#        0.057, 0.067, 0.162, 0.093, 0.095, 0.033, 0.081, 0.165, 0.091,
#        0.408, 0.093, 0.16 , 0.432, 0.125, 0.066, 0.176, 0.401, 0.067,
#        0.03 , 0.128, 0.276, 0.623, 0.329, 0.134, 0.083, 0.162, 0.148,
#        0.147, 0.314, 0.384, 0.365, 0.036, 0.058, 0.084, 0.086, 0.251,
#        0.38 , 0.244, 1.773, 0.893, 1.756, 0.178, 0.045, 0.819, 0.375,
#        0.296, 0.028, 0.175, 0.094, 0.815, 0.199, 0.11 , 0.243, 0.054,
#        0.098, 0.021, 0.457, 0.3  , 0.03 , 0.104, 0.088, 0.523, 0.269,
#        0.44 , 0.036, 0.041, 0.176, 0.352, 0.09 , 0.081, 0.791, 0.397,
#        0.016, 0.025, 0.11 , 0.188, 0.245, 0.508, 0.212, 0.389, 0.129,
#        0.294, 1.473, 0.778, 0.27 , 0.293, 0.575, 0.788, 0.576, 0.381,
#        0.285, 0.341, 0.279, 0.469, 0.331, 0.156, 0.356, 0.628, 0.444,
#        0.409, 0.015, 0.083, 0.126, 0.539, 0.258, 0.673, 0.005, 0.098,
#        0.06 , 0.12 , 0.124, 0.053, 0.13 , 0.617, 0.154, 0.334, 0.087,
#        0.199, 0.253, 0.385, 0.038, 0.15 , 0.588, 0.296, 0.186, 0.389,
#        0.183, 0.134, 0.566, 0.088, 0.107, 0.323, 0.133, 0.179, 1.135,
#        0.069, 0.007, 0.004, 0.229, 0.142, 0.453, 0.452, 0.42 , 0.244,
#        0.222, 0.206, 0.019, 1.493, 0.394, 0.381, 0.05 , 0.075, 0.654,
#        0.855, 0.457, 0.331, 0.31 , 0.17 , 0.228, 0.356, 0.102, 0.941,
#        1.696, 1.372, 2.047, 1.957, 1.645, 1.129, 1.106, 0.527, 0.231,
#        0.39 , 0.59 , 0.089, 0.134, 0.364, 0.525, 0.415, 0.62 , 0.088,
#        0.205, 0.256, 0.116, 0.322, 0.077, 0.044, 0.785, 0.421, 0.14 ,
#        0.427, 0.273, 0.049, 0.369, 0.372, 0.117, 0.107, 0.127, 0.222,
#        0.503, 0.299, 0.381, 0.048, 0.71 , 0.721, 0.047, 0.203, 0.277,
#        0.306, 0.14 , 0.165, 0.353, 0.388, 0.425, 0.384, 0.24 , 0.438,
#        0.159, 0.216, 0.277, 0.422, 0.294, 0.368, 0.684, 0.177, 0.211,
#        0.206, 0.097, 0.196, 0.214, 0.771, 0.153, 0.274, 0.31 , 0.293,
#        0.589, 0.504, 0.334, 0.124, 0.26 , 0.379, 0.344, 0.499, 0.722,
#        0.265, 0.006, 0.585, 0.498, 0.159, 0.149, 0.295, 0.106, 0.183,
#        0.299, 0.386, 0.257, 0.299, 0.461, 0.347, 0.06 , 0.065, 0.121,
#        0.245, 0.019, 0.07 , 0.247, 0.064, 0.316, 0.559, 1.256, 1.704,
#        0.713, 0.881, 0.174, 0.209, 0.214, 0.503, 0.274, 0.448, 0.231,
#        0.512, 0.144, 0.008, 0.365, 0.217, 0.09 , 0.157, 0.237, 0.597,
#        0.197, 0.786, 1.075, 0.517, 0.309, 0.014, 0.174, 0.881, 0.078,
#        0.171, 0.32 , 0.391, 0.121, 1.245, 0.285, 0.637, 0.618, 0.116,
#        0.321, 0.136, 0.682, 0.584, 0.898, 0.081, 0.386, 0.144, 0.129,
#        0.503, 1.022, 0.308, 0.063, 0.053, 0.374, 0.234, 0.336, 0.039,
#        0.007, 0.126, 0.242, 0.67 , 0.189, 0.048, 0.059, 0.525, 0.218,
#        0.048, 0.228, 0.191, 0.075, 0.006, 0.125, 0.031, 0.112, 0.045,
#        0.651, 0.447, 0.358, 0.342, 0.395, 0.615, 0.061, 0.041, 0.041,
#        0.035, 0.299, 0.267, 0.361, 0.338, 0.398, 0.218, 0.003, 0.148,
#        0.05 , 0.054, 0.213, 0.384, 0.052, 0.144, 0.106, 0.225, 0.182,
#        0.628, 0.033, 0.132, 0.212, 0.237, 0.084, 0.147, 0.008, 0.438,
#        1.915, 0.045, 0.31 , 0.523, 1.378, 0.585, 0.273, 0.29 , 0.433,
#        0.983, 0.771, 0.546, 0.08 , 0.199, 0.308, 0.173, 0.316, 0.039,
#        0.549, 0.419, 0.114, 0.471, 0.23 , 0.913, 1.278, 0.396, 0.822,
#        0.485, 0.173, 0.177, 0.113, 0.018, 0.296, 0.252, 0.542, 0.391,
#        0.34 , 0.274, 0.093, 0.129, 0.38 , 0.191, 0.295, 0.279, 0.611,
#        0.51 , 0.325, 0.619, 0.54 , 0.326, 1.046, 0.951, 0.062, 0.15 ,
#        0.015, 0.17 , 0.358, 0.309, 0.249, 0.089, 0.517, 0.563, 0.428,
#        0.004, 0.809, 1.289, 0.819, 0.097, 0.199, 0.272, 0.272, 0.004,
#        0.171, 0.271, 0.607, 0.645, 0.616, 0.197, 0.481, 0.18 , 0.037,
#        0.194, 0.175, 0.3  , 0.462, 0.064, 0.327, 0.108, 0.098, 0.196,
#        0.761, 0.013, 0.447, 0.344, 0.346, 0.441, 0.254, 0.038, 0.355,
#        0.272, 0.136, 0.413, 0.44 , 0.021, 0.191, 0.029, 0.084, 0.215,
#        0.043, 0.178, 0.26 , 0.759, 0.151, 0.271, 0.575, 0.257, 0.041,
#        0.222, 0.532, 0.841, 0.16 , 0.165, 0.075, 0.077, 0.166, 0.548,
#        0.523, 0.257, 0.287, 0.248, 0.251, 0.217, 0.599, 0.072, 0.495,
#        0.005, 0.383, 0.448, 0.057, 0.104, 0.023, 0.586, 0.64 , 0.433,
#        0.337, 0.275, 0.418, 0.134, 0.555])
