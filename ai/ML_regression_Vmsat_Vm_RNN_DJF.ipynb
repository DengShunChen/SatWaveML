# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import sqlite3
import json
from datetime import datetime

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

print(tf.__version__)
# Out:
# 2.4.1

# %%
from scipy.stats import spearmanr

# %% [markdown]
# ## Read in data
#
# read in station name

# %%
df = pd.read_json('../ML_data_DJF.json')

# %% [markdown]
# ## clean data

# %%
dataset = df[['STN','ST','DATETIME','H','Temp','P','Vm','Vmsat']]

df_index = (dataset['DATETIME']>datetime(2015,1,1,0)) & (dataset['DATETIME']<datetime(2020,1,1,0))
dataset = dataset[df_index]

#stnlist=['新竹浮標','龜山島浮標','臺東外洋浮標','龍洞浮標','小琉球浮標','花蓮浮標','東沙島浮標','馬祖浮標']
#stnlist=['東沙島浮標']
#stnlist=['新竹浮標','臺東外洋浮標','東沙島浮標','馬祖浮標']
stnlist=['臺東外洋浮標','東沙島浮標','馬祖浮標']

dataset = dataset[dataset['STN'].isin(stnlist)]
dataset = dataset.dropna()

# %%
plt.figure(figsize=(16,8),dpi=200)
g = sns.FacetGrid(dataset, col="STN", col_wrap=2, height=3, aspect=3)
g.map(sns.lineplot, 'DATETIME','Vm',color='k')
g.map(sns.lineplot, 'DATETIME','Vmsat',color='r')
plt.legend(labels=['Buoy Wind','Satellite Wind'])

# %%
dataset.pop('DATETIME')
dataset.pop('ST')
dataset.pop('STN')
# Out:
# 154431    臺東外洋浮標
# 154437    臺東外洋浮標
# 154443    臺東外洋浮標
# 154449    臺東外洋浮標
# 154455    臺東外洋浮標
#            ...
# 877101      馬祖浮標
# 877107      馬祖浮標
# 877113      馬祖浮標
# 877119      馬祖浮標
# 877125      馬祖浮標
# Name: STN, Length: 1685, dtype: object

# %%
dataset.isna().sum()
# Out:
# H        0
# Temp     0
# P        0
# Vm       0
# Vmsat    0
# dtype: int64

# %% [markdown]
# Drop those rows to keep this initial tutorial simple.

# %%
dataset = dataset.dropna()
dataset.isna().sum()
# Out:
# H        0
# Temp     0
# P        0
# Vm       0
# Vmsat    0
# dtype: int64

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt

host = host_subplot(111, axes_class=AA.Axes)
plt.subplots_adjust(right=0.75)

par1 = host.twinx()
par2 = host.twinx()

offset = 60
new_fixed_axis = par2.get_grid_helper().new_fixed_axis
par2.axis["right"] = new_fixed_axis(loc="right", axes=par2,
                                        offset=(offset, 0))

par2.axis["right"].toggle(all=True)


host.set_xlabel("Date")
host.set_ylabel("Pressure")
par1.set_ylabel("Temperature")
par2.set_ylabel("Velocity")

p1, = host.plot(dataset['P'], label="Pressure")
p2, = par1.plot(dataset['Temp'], label="Temperature")
p3, = par2.plot(dataset['Vm'], label="Velocity")

host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())
par2.axis["right"].label.set_color(p3.get_color())

host.legend()

# %% [markdown]
# ### Split the data into train and test
#
# Now split the dataset into a training set and a test set.
#
# Use the test set in the final evaluation of your models.

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %% [markdown]
# ### Inspect the data
#
# Have a quick look at the joint distribution of a few pairs of columns from the training set.

# %%
sns.pairplot(train_dataset[['H', 'P', 'Temp', 'Vm','Vmsat']], diag_kind='kde')

# %% [markdown]
# Also look at the overall statistics, note how each feature covers a very different range:

# %%
train_dataset.describe().transpose()
# Out:
#         count         mean       std          min          25%         50%  \
# H      1348.0     2.412945  0.996230     0.560000     1.680000     2.25500
# Temp   1348.0    23.958605  3.736029    12.800000    22.100000    25.40000
# P      1348.0  1017.600964  4.366773  1007.900000  1014.575000  1017.10000
# Vm     1348.0     8.823516  2.398936     1.100000     7.300000     8.80000
# Vmsat  1348.0    10.139725  2.639663     1.293657     8.672546    10.14273
#
#                75%          max
# H         3.060000     7.680000
# Temp     26.700000    29.000000
# P      1020.000000  1035.200000
# Vm       10.400000    15.600000
# Vmsat    11.761087    21.665361

# %% [markdown]
# ### Split features from labels
#
# Separate the target value, the "label", from the features. This label is the value that you will train the model to predict.

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('Vm')
test_labels = test_features.pop('Vm')

# %% [markdown]
# ## Normalization
#
# In the table of statistics it's easy to see how different the ranges of each feature are.

# %%
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#               mean       std
# H         2.412945  0.996230
# Temp     23.958605  3.736029
# P      1017.600964  4.366773
# Vm        8.823516  2.398936
# Vmsat    10.139725  2.639663

# %% [markdown]
# It is good practice to normalize features that use different scales and ranges.
#
# One reason this is important is because the features are multiplied by the model weights. So the scale of the outputs and the scale of the gradients are affected by the scale of the inputs.
#
# Although a model *might* converge without feature normalization, normalization makes training much more stable.

# %% [markdown]
# ### The Normalization layer
# The `preprocessing.Normalization` layer is a clean and simple way to build that preprocessing into your model.
#
# The first step is to create the layer:

# %%
normalizer = preprocessing.Normalization(axis=-1)

# %% [markdown]
# Then `.adapt()` it to the data:

# %%
normalizer.adapt(np.array(train_features))

# %% [markdown]
# This calculates the mean and variance, and stores them in the layer.

# %%
print(normalizer.mean.numpy())
# Out:
# [   2.413   23.959 1017.601   10.14 ]

# %% [markdown]
# When the layer is called it returns the input data, with each feature independently normalized:

# %%
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[   2.93   25.8  1012.     10.18]]
#
# Normalized: [[ 0.52  0.49 -1.28  0.02]]

# %% [markdown]
# ## Linear regression
#
# Before building a DNN model, start with a linear regression.

# %% [markdown]
# ### One Variable
#
# Start with a single-variable linear regression, to predict `H` from `Vmsat`.
#
# Training a model with `tf.keras` typically starts by defining the model architecture.
#
# In this case use a `keras.Sequential` model. This model represents a sequence of steps. In this case there are two steps:
#
# * Normalize the input `Vmsat`.
# * Apply a linear transformation ($y = mx+b$) to produce 1 output using `layers.Dense`.
#
# The number of _inputs_ can either be set by the `input_shape` argument, or automatically when the model is run for the first time.

# %% [markdown]
# First create the horsepower `Normalization` layer:

# %%
Vmsat = np.array(train_features['Vmsat'])

Vmsat_normalizer = preprocessing.Normalization(input_shape=[1,], axis=None)
Vmsat_normalizer.adapt(Vmsat)

# %% [markdown]
# Build the sequential model:

# %%
Vmsat_model = tf.keras.Sequential([
    Vmsat_normalizer,
    layers.Dense(units=1)
])

Vmsat_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_1 (Normalizati (None, 1)                 3
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 5
# Trainable params: 2
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# This model will predict `H` from `Vmsat`.
#
# Run the untrained model on the first 10 Vmsat values. The output won't be good, but you'll see that it has the expected shape, `(10,1)`:

# %%
Vmsat_model.predict(Vmsat[:10])
# Out:
# array([[ 0.013],
#        [ 1.533],
#        [ 0.367],
#        [ 0.929],
#        [-1.693],
#        [-2.51 ],
#        [-0.411],
#        [-1.103],
#        [-0.101],
#        [ 0.325]], dtype=float32)

# %% [markdown]
# Once the model is built, configure the training procedure using the `Model.compile()` method. The most important arguments to compile are the `loss` and the `optimizer` since these define what will be optimized (`mean_absolute_error`) and how (using the `optimizers.Adam`).

# %%
Vmsat_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %% [markdown]
# Once the training is configured, use `Model.fit()` to execute the training:

# %%
# %%time
history = Vmsat_model.fit(
    train_features['Vmsat'], train_labels,
    epochs=100,
    batch_size=16,
    # suppress logging
    verbose=0,
    # Calculate validation results on 20% of the training data
    validation_split = 0.2)
# Out:
# CPU times: user 57.6 s, sys: 8min 2s, total: 9min
# Wall time: 31.2 s

# %% [markdown]
# Visualize the model's training progress using the stats stored in the `history` object.

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  val_loss  epoch
# 95  0.889470  0.802679     95
# 96  0.877891  0.785447     96
# 97  0.888491  0.810550     97
# 98  0.881817  0.784203     98
# 99  0.884147  0.797211     99

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 3])
  plt.xlabel('Epoch')
  plt.ylabel('Error [H]')
  plt.legend()
  plt.grid(True)

# %%
plot_loss(history)

# %% [markdown]
# Collect the results on the test set, for later:

# %%
test_results = {}

test_results['Vmsat_model'] = Vmsat_model.evaluate(
    test_features['Vmsat'],
    test_labels, verbose=0)

# %% [markdown]
# Since this is a single variable regression it's easy to look at the model's predictions as a function of the input:

# %%
def plot_Vmsat(x, y):
  plt.scatter(train_features['Vmsat'], train_labels, label='Data')
  plt.plot(x, y, color='k', label='Predictions')
  plt.xlabel('Vmsat')
  plt.ylabel('Vm')
  plt.legend()

# %%
x = tf.linspace(0.0, 15, 251)
y = Vmsat_model.predict(x)

# %%
plt.figure(figsize=(10,6),dpi=200)
plot_Vmsat(x,y)

# %% [markdown]
# ### Multiple inputs

# %% [markdown]
# You can use an almost identical setup to make predictions based on multiple inputs. This model still does the same $y = mx+b$ except that $m$ is a matrix and $b$ is a vector.
#
# This time use the `Normalization` layer that was adapted to the whole dataset.

# %%
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

# %% [markdown]
# When you call this model on a batch of inputs, it produces `units=1` outputs for each example.

# %%
linear_model.predict(train_features[:10])
# Out:
# array([[ 0.201],
#        [ 1.237],
#        [ 0.042],
#        [-0.477],
#        [-0.211],
#        [ 0.913],
#        [-0.592],
#        [-0.127],
#        [ 0.056],
#        [ 0.767]], dtype=float32)

# %% [markdown]
# When you call the model it's weight matrices will be built. Now you can see that the `kernel` (the $m$ in $y=mx+b$) has a shape of `(4,1)`.

# %%
linear_model.layers[1].kernel
# Out:
# <tf.Variable 'dense_1/kernel:0' shape=(4, 1) dtype=float32, numpy=
# array([[ 0.86 ],
#        [-0.653],
#        [-0.064],
#        [-0.422]], dtype=float32)>

# %% [markdown]
# Use the same `compile` and `fit` calls as for the single input `Vmsat` model:

# %%
linear_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_features, train_labels, 
    epochs=100,
    # suppress logging
    verbose=0,
    # Calculate validation results on 20% of the training data
    validation_split = 0.2)
# Out:
# CPU times: user 40.8 s, sys: 5min 29s, total: 6min 10s
# Wall time: 26.2 s

# %%
plot_loss(history)

# %%
test_results['linear_model'] = linear_model.evaluate(
    test_features, test_labels, verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [Vm]']).T
# Out:
#               Mean absolute error [Vm]
# Vmsat_model                   0.881307
# linear_model                  0.888481

# %% [markdown]
# ## A DNN regression

# %% [markdown]
# The previous section implemented linear models for single and multiple inputs.
#
# This section implements single-input and multiple-input DNN models. The code is basically the same except the model is expanded to include some "hidden"  non-linear layers. The name "hidden" here just means not directly connected to the inputs or outputs.

# %% [markdown]
# These models will contain a few more layers than the linear model:
#
# * The normalization layer.
# * Two hidden, nonlinear, `Dense` layers using the `relu` nonlinearity.
# * A linear single-output layer.
#
# Both will use the same training procedure so the `compile` method is included in the `build_and_compile_model` function below.

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(64, activation='relu', name="layer1"),
      layers.Dense(64, activation='relu', name="layer2"),
      layers.Dense(1, name="layer3")
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %% [markdown]
# ### One variable

# %% [markdown]
# Start with a DNN model for a single input: "Vmsat"

# %%
dnn_Vmsat_model = build_and_compile_model(Vmsat_normalizer)

# %% [markdown]
# This model has quite a few more trainable parameters than the linear models.

# %%
dnn_Vmsat_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_1 (Normalizati (None, 1)                 3
# _________________________________________________________________
# layer1 (Dense)               (None, 64)                128
# _________________________________________________________________
# layer2 (Dense)               (None, 64)                4160
# _________________________________________________________________
# layer3 (Dense)               (None, 1)                 65
# =================================================================
# Total params: 4,356
# Trainable params: 4,353
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Train the model:

# %%
# %%time
history = dnn_Vmsat_model.fit(
    train_features['Vmsat'], train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# CPU times: user 57.7 s, sys: 7min 3s, total: 8min
# Wall time: 26.8 s

# %%
plot_loss(history)

# %%
x = tf.linspace(0.0, 15, 251)
y = dnn_Vmsat_model.predict(x)

# %%
plt.figure(figsize=(10,6),dpi=200)
plot_Vmsat(x,y)

# %%
test_results['dnn_Vmsat_model'] = dnn_Vmsat_model.evaluate(
    test_features['Vmsat'], test_labels,
    verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [Vm]']).T
# Out:
#                  Mean absolute error [Vm]
# Vmsat_model                      0.881307
# linear_model                     0.888481
# dnn_Vmsat_model                  0.875811

# %% [markdown]
# ### Full model

# %% [markdown]
# If you repeat this process using all the inputs it slightly improves the performance on the validation dataset.

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization (Normalization (None, 4)                 9
# _________________________________________________________________
# layer1 (Dense)               (None, 64)                320
# _________________________________________________________________
# layer2 (Dense)               (None, 64)                4160
# _________________________________________________________________
# layer3 (Dense)               (None, 1)                 65
# =================================================================
# Total params: 4,554
# Trainable params: 4,545
# Non-trainable params: 9
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# CPU times: user 46.8 s, sys: 6min 16s, total: 7min 3s
# Wall time: 26.1 s

# %%
plot_loss(history)

# %%
test_results['dnn_model'] = dnn_model.evaluate(test_features, test_labels, verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [Vm]']).T
# Out:
#                  Mean absolute error [Vm]
# Vmsat_model                      0.881307
# linear_model                     0.888481
# dnn_Vmsat_model                  0.875811
# dnn_model                        0.888539

# %%
test_predictions = dnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Vm]')
plt.ylabel('Predictions [Vm]')
lims = [0, 15]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [Vm]')
_ = plt.ylabel('Count')

# %%
plt.figure(figsize=(10,6),dpi=200)
x = tf.linspace(0.0, 25, 251)
y1 = dnn_model.predict(pd.DataFrame(x))
y2 = dnn_Vmsat_model.predict(pd.DataFrame(x))
y4 = Vmsat_model.predict(pd.DataFrame(x))

plt.scatter(train_features['Vmsat'], train_labels, label='Data',alpha=0.2)
#plt.plot(x, y1, color='b', label='DNN_multi')
plt.plot(x, x, color='k')
plt.plot(x, y4, color='g', label='Linear')
plt.plot(x, y2, color='r', label='DNN')
plt.xlabel('Vmsat(m/s)')
plt.ylabel('Vm(m/s)')
plt.legend()

# %%
linear_model.save(   'saved_model/Vmsat_Vm_linear_model_DJF')
Vmsat_model.save(    'saved_model/Vmsat_Vm_Vmsat_model_DJF')
dnn_model.save(      'saved_model/Vmsat_Vm_dnn_model_DJF')
dnn_Vmsat_model.save('saved_model/Vmsat_Vm_dnn_Vmsat_model_DJF')
# Out:
# INFO:tensorflow:Assets written to: saved_model/Vmsat_Vm_linear_model_DJF/assets
# INFO:tensorflow:Assets written to: saved_model/Vmsat_Vm_Vmsat_model_DJF/assets
# INFO:tensorflow:Assets written to: saved_model/Vmsat_Vm_dnn_model_DJF/assets
# INFO:tensorflow:Assets written to: saved_model/Vmsat_Vm_dnn_Vmsat_model_DJF/assets

# %% [markdown]
# # RNN

# %%
def build_and_compile_model_RNN(Norm):
  model = keras.Sequential([
      Norm,
      layers.SimpleRNN(64,  unroll=False, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
def build_and_compile_model_LSTM(Norm):
  model = keras.Sequential([
      Norm,
      layers.LSTM(64, input_shape=(1,1), activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
Vmsat_normalizer = preprocessing.Normalization(input_shape=[1,1], axis=None)
Vmsat_normalizer.adapt(Vmsat)

# %%
rnn_Vmsat_model = build_and_compile_model_RNN(Vmsat_normalizer)
#rnn_Vmsat_model = build_and_compile_model_LSTM(Vmsat_normalizer)

# %%
rnn_Vmsat_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_2 (Normalizati (None, 1, 1)              3
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 64)                4224
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,292
# Trainable params: 4,289
# Non-trainable params: 3
# _________________________________________________________________

# %%
# %%time
history = rnn_Vmsat_model.fit(
    train_features['Vmsat'], train_labels,
    validation_split=0.2,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 2s 21ms/step - loss: 8.6605 - val_loss: 8.2834
# Epoch 2/100
# 34/34 [==============================] - 0s 12ms/step - loss: 8.1697 - val_loss: 7.8038
# Epoch 3/100
# 34/34 [==============================] - 0s 12ms/step - loss: 7.6272 - val_loss: 7.2467
# Epoch 4/100
# 34/34 [==============================] - 0s 8ms/step - loss: 6.9380 - val_loss: 6.5690
# Epoch 5/100
# 34/34 [==============================] - 0s 5ms/step - loss: 6.3144 - val_loss: 5.7580
# Epoch 6/100
# 34/34 [==============================] - 0s 6ms/step - loss: 5.6210 - val_loss: 4.8188
# Epoch 7/100
# 34/34 [==============================] - 0s 6ms/step - loss: 4.5768 - val_loss: 3.7333
# Epoch 8/100
# 34/34 [==============================] - 0s 6ms/step - loss: 3.5486 - val_loss: 2.4308
# Epoch 9/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.1964 - val_loss: 1.2540
# Epoch 10/100
# 34/34 [==============================] - 0s 6ms/step - loss: 1.2242 - val_loss: 1.0117
# Epoch 11/100
# 34/34 [==============================] - 0s 6ms/step - loss: 1.1052 - val_loss: 0.9622
# Epoch 12/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.9662 - val_loss: 0.9255
# Epoch 13/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.9437 - val_loss: 0.8983
# Epoch 14/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.9539 - val_loss: 0.8728
# Epoch 15/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.9142 - val_loss: 0.8504
# Epoch 16/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.9001 - val_loss: 0.8401
# Epoch 17/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.8955 - val_loss: 0.8258
# Epoch 18/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.8440 - val_loss: 0.8234
# Epoch 19/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.8629 - val_loss: 0.8309
# Epoch 20/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.9048 - val_loss: 0.8178
# Epoch 21/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.8849 - val_loss: 0.8181
# Epoch 22/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.9068 - val_loss: 0.8197
# Epoch 23/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.8547 - val_loss: 0.8219
# Epoch 24/100
# 34/34 [==============================] - 0s 9ms/step - loss: 0.8842 - val_loss: 0.8181
# Epoch 25/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.8998 - val_loss: 0.8139
# Epoch 26/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8593 - val_loss: 0.8103
# Epoch 27/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.9184 - val_loss: 0.8112
# Epoch 28/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8781 - val_loss: 0.8123
# Epoch 29/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8871 - val_loss: 0.8139
# Epoch 30/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.8616 - val_loss: 0.8085
# Epoch 31/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8298 - val_loss: 0.8085
# Epoch 32/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.9177 - val_loss: 0.8111
# Epoch 33/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8982 - val_loss: 0.8081
# Epoch 34/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8455 - val_loss: 0.8082
# Epoch 35/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8502 - val_loss: 0.8077
# Epoch 36/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8550 - val_loss: 0.8037
# Epoch 37/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8456 - val_loss: 0.8010
# Epoch 38/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8619 - val_loss: 0.8065
# Epoch 39/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.8540 - val_loss: 0.8071
# Epoch 40/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.8706 - val_loss: 0.8011
# Epoch 41/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.8775 - val_loss: 0.8053
# Epoch 42/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8610 - val_loss: 0.8026
# Epoch 43/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.8534 - val_loss: 0.8024
# Epoch 44/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.8859 - val_loss: 0.7994
# Epoch 45/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8596 - val_loss: 0.8004
# Epoch 46/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8606 - val_loss: 0.8035
# Epoch 47/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8471 - val_loss: 0.8043
# Epoch 48/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8239 - val_loss: 0.7986
# Epoch 49/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8634 - val_loss: 0.8021
# Epoch 50/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8645 - val_loss: 0.7999
# Epoch 51/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8558 - val_loss: 0.8022
# Epoch 52/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8597 - val_loss: 0.7987
# Epoch 53/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8514 - val_loss: 0.7976
# Epoch 54/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8614 - val_loss: 0.7970
# Epoch 55/100
# 34/34 [==============================] - 0s 9ms/step - loss: 0.8491 - val_loss: 0.8057
# Epoch 56/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8798 - val_loss: 0.7965
# Epoch 57/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8476 - val_loss: 0.8048
# Epoch 58/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8823 - val_loss: 0.7960
# Epoch 59/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.8671 - val_loss: 0.8013
# Epoch 60/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8673 - val_loss: 0.7997
# Epoch 61/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8580 - val_loss: 0.7964
# Epoch 62/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8843 - val_loss: 0.7954
# Epoch 63/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8629 - val_loss: 0.7948
# Epoch 64/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8407 - val_loss: 0.7995
# Epoch 65/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.9073 - val_loss: 0.7927
# Epoch 66/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8689 - val_loss: 0.7938
# Epoch 67/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8731 - val_loss: 0.7979
# Epoch 68/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8693 - val_loss: 0.7902
# Epoch 69/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.8470 - val_loss: 0.7935
# Epoch 70/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8846 - val_loss: 0.7962
# Epoch 71/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8356 - val_loss: 0.7906
# Epoch 72/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8772 - val_loss: 0.7934
# Epoch 73/100
# 34/34 [==============================] - 0s 13ms/step - loss: 0.8580 - val_loss: 0.7929
# Epoch 74/100
# 34/34 [==============================] - 0s 9ms/step - loss: 0.8492 - val_loss: 0.7966
# Epoch 75/100
# 34/34 [==============================] - 1s 14ms/step - loss: 0.9093 - val_loss: 0.7928
# Epoch 76/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.8951 - val_loss: 0.7957
# Epoch 77/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8469 - val_loss: 0.7907
# Epoch 78/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.8908 - val_loss: 0.7954
# Epoch 79/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8837 - val_loss: 0.7911
# Epoch 80/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8934 - val_loss: 0.7946
# Epoch 81/100
# 34/34 [==============================] - 0s 9ms/step - loss: 0.9010 - val_loss: 0.7974
# Epoch 82/100
# 34/34 [==============================] - 0s 9ms/step - loss: 0.8574 - val_loss: 0.7948
# Epoch 83/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.8334 - val_loss: 0.7948
# Epoch 84/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8972 - val_loss: 0.7969
# Epoch 85/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8961 - val_loss: 0.7926
# Epoch 86/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8855 - val_loss: 0.7954
# Epoch 87/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8461 - val_loss: 0.7983
# Epoch 88/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8699 - val_loss: 0.7942
# Epoch 89/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.9348 - val_loss: 0.7949
# Epoch 90/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8656 - val_loss: 0.7950
# Epoch 91/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8725 - val_loss: 0.7942
# Epoch 92/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8717 - val_loss: 0.7963
# Epoch 93/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.8514 - val_loss: 0.7892
# Epoch 94/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.8708 - val_loss: 0.7929
# Epoch 95/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.8591 - val_loss: 0.7933
# Epoch 96/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.8792 - val_loss: 0.7917
# Epoch 97/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.8913 - val_loss: 0.7937
# Epoch 98/100
# 34/34 [==============================] - 0s 9ms/step - loss: 0.8221 - val_loss: 0.7942
# Epoch 99/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.8854 - val_loss: 0.7959
# Epoch 100/100
# 34/34 [==============================] - 1s 18ms/step - loss: 0.8848 - val_loss: 0.7907
# CPU times: user 1min 36s, sys: 10min 40s, total: 12min 17s
# Wall time: 27 s

# %%
plot_loss(history)

# %%
test_results['rnn_Vmsat_model'] = rnn_Vmsat_model.evaluate(
    test_features['Vmsat'], test_labels,
    verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [Vm]']).T
# Out:
#                  Mean absolute error [Vm]
# Vmsat_model                      0.881307
# linear_model                     0.888481
# dnn_Vmsat_model                  0.875811
# dnn_model                        0.888539
# rnn_Vmsat_model                  0.892238

# %% [markdown]
# ### Multi-variable

# %%
normalizer = preprocessing.Normalization(input_shape=[4,1], axis=None)
normalizer.adapt(np.array(train_features))

# %%
rnn_model = build_and_compile_model_RNN(normalizer)
rnn_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_3 (Normalizati (None, 4, 1)              3
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 64)                4224
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,292
# Trainable params: 4,289
# Non-trainable params: 3
# _________________________________________________________________

# %%
# %%time
history = rnn_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 2s 30ms/step - loss: 7.9542 - val_loss: 4.7364
# Epoch 2/100
# 34/34 [==============================] - 0s 7ms/step - loss: 3.2416 - val_loss: 1.6718
# Epoch 3/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.8928 - val_loss: 1.6438
# Epoch 4/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.8998 - val_loss: 1.6421
# Epoch 5/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9660 - val_loss: 1.6355
# Epoch 6/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.9311 - val_loss: 1.6418
# Epoch 7/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.9718 - val_loss: 1.6356
# Epoch 8/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.8769 - val_loss: 1.6399
# Epoch 9/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.9341 - val_loss: 1.6525
# Epoch 10/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.9319 - val_loss: 1.6502
# Epoch 11/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.9253 - val_loss: 1.6454
# Epoch 12/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9030 - val_loss: 1.6438
# Epoch 13/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9509 - val_loss: 1.6353
# Epoch 14/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9586 - val_loss: 1.6364
# Epoch 15/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.9367 - val_loss: 1.6380
# Epoch 16/100
# 34/34 [==============================] - 0s 13ms/step - loss: 1.9574 - val_loss: 1.7148
# Epoch 17/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9219 - val_loss: 1.7925
# Epoch 18/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9779 - val_loss: 1.6533
# Epoch 19/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.9453 - val_loss: 1.6388
# Epoch 20/100
# 34/34 [==============================] - 0s 13ms/step - loss: 1.8894 - val_loss: 1.6345
# Epoch 21/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.9774 - val_loss: 1.6559
# Epoch 22/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9737 - val_loss: 1.6899
# Epoch 23/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9648 - val_loss: 1.6495
# Epoch 24/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9280 - val_loss: 1.7161
# Epoch 25/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9505 - val_loss: 1.6360
# Epoch 26/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.8906 - val_loss: 1.6607
# Epoch 27/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9260 - val_loss: 1.6324
# Epoch 28/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9247 - val_loss: 1.6433
# Epoch 29/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.0042 - val_loss: 1.7039
# Epoch 30/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9383 - val_loss: 1.6439
# Epoch 31/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9253 - val_loss: 1.6387
# Epoch 32/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9362 - val_loss: 1.6832
# Epoch 33/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9866 - val_loss: 1.6384
# Epoch 34/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9572 - val_loss: 1.6469
# Epoch 35/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.9474 - val_loss: 1.6314
# Epoch 36/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.9895 - val_loss: 1.6351
# Epoch 37/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.8935 - val_loss: 1.6386
# Epoch 38/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9569 - val_loss: 1.6728
# Epoch 39/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9953 - val_loss: 1.6307
# Epoch 40/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9336 - val_loss: 1.6310
# Epoch 41/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9310 - val_loss: 1.6451
# Epoch 42/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9490 - val_loss: 1.6678
# Epoch 43/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9399 - val_loss: 1.6986
# Epoch 44/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9090 - val_loss: 1.7202
# Epoch 45/100
# 34/34 [==============================] - 0s 7ms/step - loss: 1.9738 - val_loss: 1.6542
# Epoch 46/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.8433 - val_loss: 1.6562
# Epoch 47/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.9264 - val_loss: 1.6297
# Epoch 48/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.8951 - val_loss: 1.6538
# Epoch 49/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9799 - val_loss: 1.6427
# Epoch 50/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.9786 - val_loss: 1.6354
# Epoch 51/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.8764 - val_loss: 1.6279
# Epoch 52/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.8438 - val_loss: 1.6295
# Epoch 53/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9091 - val_loss: 1.6284
# Epoch 54/100
# 34/34 [==============================] - 0s 13ms/step - loss: 1.9538 - val_loss: 1.6443
# Epoch 55/100
# 34/34 [==============================] - 0s 13ms/step - loss: 2.0031 - val_loss: 1.6313
# Epoch 56/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.8959 - val_loss: 1.6269
# Epoch 57/100
# 34/34 [==============================] - 0s 15ms/step - loss: 1.9935 - val_loss: 1.6289
# Epoch 58/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8348 - val_loss: 1.6317
# Epoch 59/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9743 - val_loss: 1.6267
# Epoch 60/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9193 - val_loss: 1.6282
# Epoch 61/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9675 - val_loss: 1.6300
# Epoch 62/100
# 34/34 [==============================] - 0s 13ms/step - loss: 1.9454 - val_loss: 1.6290
# Epoch 63/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9410 - val_loss: 1.6298
# Epoch 64/100
# 34/34 [==============================] - 1s 27ms/step - loss: 1.8985 - val_loss: 1.6261
# Epoch 65/100
# 34/34 [==============================] - 0s 13ms/step - loss: 1.9284 - val_loss: 1.6582
# Epoch 66/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.9331 - val_loss: 1.6367
# Epoch 67/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9710 - val_loss: 1.6248
# Epoch 68/100
# 34/34 [==============================] - 1s 22ms/step - loss: 1.9857 - val_loss: 1.6356
# Epoch 69/100
# 34/34 [==============================] - 0s 13ms/step - loss: 1.9053 - val_loss: 1.6241
# Epoch 70/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9479 - val_loss: 1.6242
# Epoch 71/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.9269 - val_loss: 1.6280
# Epoch 72/100
# 34/34 [==============================] - 1s 27ms/step - loss: 1.8795 - val_loss: 1.6247
# Epoch 73/100
# 34/34 [==============================] - 1s 14ms/step - loss: 1.9565 - val_loss: 1.6287
# Epoch 74/100
# 34/34 [==============================] - 0s 13ms/step - loss: 1.9121 - val_loss: 1.6689
# Epoch 75/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.8637 - val_loss: 1.6923
# Epoch 76/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9657 - val_loss: 1.7027
# Epoch 77/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9080 - val_loss: 1.6272
# Epoch 78/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9309 - val_loss: 1.6414
# Epoch 79/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.8896 - val_loss: 1.6515
# Epoch 80/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9010 - val_loss: 1.6358
# Epoch 81/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9457 - val_loss: 1.6458
# Epoch 82/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.9775 - val_loss: 1.6275
# Epoch 83/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.9349 - val_loss: 1.6258
# Epoch 84/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9012 - val_loss: 1.6251
# Epoch 85/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.9298 - val_loss: 1.6230
# Epoch 86/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.8185 - val_loss: 1.6355
# Epoch 87/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.8864 - val_loss: 1.6322
# Epoch 88/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.9693 - val_loss: 1.6567
# Epoch 89/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.8810 - val_loss: 1.6419
# Epoch 90/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.9307 - val_loss: 1.6454
# Epoch 91/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.9041 - val_loss: 1.6220
# Epoch 92/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.8993 - val_loss: 1.6413
# Epoch 93/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.9249 - val_loss: 1.6256
# Epoch 94/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.8737 - val_loss: 1.6213
# Epoch 95/100
# 34/34 [==============================] - 0s 13ms/step - loss: 1.9151 - val_loss: 1.6289
# Epoch 96/100
# 34/34 [==============================] - 1s 22ms/step - loss: 1.8751 - val_loss: 1.6240
# Epoch 97/100
# 34/34 [==============================] - 1s 19ms/step - loss: 1.9452 - val_loss: 1.6233
# Epoch 98/100
# 34/34 [==============================] - 0s 12ms/step - loss: 1.8864 - val_loss: 1.6546
# Epoch 99/100
# 34/34 [==============================] - 1s 14ms/step - loss: 1.8796 - val_loss: 1.6265
# Epoch 100/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.8790 - val_loss: 1.6258
# CPU times: user 2min 45s, sys: 19min 59s, total: 22min 44s
# Wall time: 40.9 s

# %%
test_results['rnn_model'] = rnn_model.evaluate(
    test_features, test_labels,
    verbose=0)

# %%
plt.figure(figsize=(10,6),dpi=200)
x = tf.linspace(0.0, 25, 251)
y1 = rnn_Vmsat_model.predict(x)
y2 = dnn_Vmsat_model.predict(x)
y4 = Vmsat_model.predict(x)

plt.scatter(train_features['Vmsat'], train_labels, label='Data',alpha=0.2)
#plt.plot(x, y1, color='b', label='DNN_multi')
#plt.plot(x, x, color='k')
plt.plot(x, y4, color='g', label='Linear')
plt.plot(x, y2, color='r', label='DNN')
plt.plot(x, y1, color='b', label='RNN')
plt.xlabel('Vmsat(m/s)')
plt.ylabel('Vm(m/s)')
plt.legend()

# %%
test_predictions = rnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [H]')
plt.ylabel('Predictions [H]')
lims = [0, 8]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [H]')
_ = plt.ylabel('Count')

# %%
rnn_model.save(   'saved_model/Vmsat_Vm_rnn_model_DJF')
rnn_Vmsat_model.save('saved_model/Vmsat_Vm_rnn_Vmsat_model_DJF')
# Out:
# INFO:tensorflow:Assets written to: saved_model/Vmsat_Vm_rnn_model_DJF/assets
# INFO:tensorflow:Assets written to: saved_model/Vmsat_Vm_rnn_Vmsat_model_DJF/assets

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge

# %%
svr = GridSearchCV(SVR(kernel='rbf', gamma=0.1),
                   param_grid={"C": [1e0, 1e1, 1e2, 1e3],
                               "gamma": np.logspace(-2, 2, 5)})

kr = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1),
                  param_grid={"alpha": [1e0, 0.1, 1e-2, 1e-3],
                              "gamma": np.logspace(-2, 2, 5)})

# %%
history = svr.fit(np.array(train_features['Vmsat']).reshape(-1,1), train_labels)

# %%
train_sizes, train_scores_svr, test_scores_svr = learning_curve(
    svr,
    np.array(test_features['Vmsat']).reshape(-1,1),
    test_labels,
    train_sizes=np.linspace(0.1, 1, 10),
    scoring="neg_mean_absolute_error",
    cv=10,
)

# %%
#plt.plot(train_sizes, -test_scores_kr.mean(1), "o--", color="g", label="KRR")
plt.plot(train_sizes, -test_scores_svr.mean(1), "o--", color="r", label="SVR")
plt.xlabel("Train size")
plt.ylabel("Mean Absolute Error")
plt.title("Learning curves")
plt.legend(loc="best")

# %%
svr.predict(np.array(train_features['Vmsat']).reshape(-1,1))
# Out:
# array([ 8.922, 12.6  ,  9.773, ...,  8.688,  9.963,  9.877])

# %%
import joblib
joblib.dump(svr, 'saved_model/Vmsat_Vm_svr_Vm_model_DJF')
# Out:
# ['saved_model/Vmsat_Vm_svr_Vm_model_DJF']

# %%
svr2 = joblib.load("saved_model/Vmsat_Vm_svr_Vm_model_DJF")

# %%
svr2.predict(np.array(train_features['Vmsat']).reshape(-1,1))
# Out:
# array([ 8.922, 12.6  ,  9.773, ...,  8.688,  9.963,  9.877])

# %%
test_predictions = svr2.predict(np.asarray(test_features['Vmsat'])[:,None]).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Vmsat]')
plt.ylabel('Predictions [Vmsat]')
lims = [0, 15]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [Vmsat]')
_ = plt.ylabel('Count')

# %% [markdown]
# ## Multi-variable

# %%
history = svr.fit(np.array(train_features), train_labels)

# %%
train_sizes_mv, train_scores_svr_mv, test_scores_svr_mv = learning_curve(
    svr,
    np.array(test_features),
    test_labels,
    train_sizes=np.linspace(0.1, 1, 10),
    scoring="neg_mean_absolute_error",
    cv=10,
)

# %%
import joblib
joblib.dump(svr, 'saved_model/Vmsat_Vm_svr_model_DJF')
# Out:
# ['saved_model/Vmsat_Vm_svr_model_DJF']

# %%
svr = joblib.load("saved_model/Vmsat_Vm_svr_model_DJF")

# %%
svr.predict(np.array(train_features))
# Out:
# array([ 9.272, 12.525,  9.876, ...,  8.6  ,  9.866, 10.452])

# %%
test_predictions = svr.predict(np.asarray(test_features)).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Vmsat]')
plt.ylabel('Predictions [Vmsat]')
lims = [0, 15]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [Vmsat]')
_ = plt.ylabel('Count')
